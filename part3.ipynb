# %%
ES_TRAIN_DATA_FILE = "./ES/train"
ES_TEST_DATA_FILE = "./ES/dev.in"
ES_ACTUAL_DATA_FILE = "./ES/dev.out"
ES_PART1_PREDICTED_DATA_FILE = "./ES/dev.p1.out"
ES_PART2_PREDICTED_DATA_FILE = "./ES/dev.p2.out"
ES_PART3_PREDICTED_DATA_FILE = "./ES/dev.p3.out"
ES_PART4_PREDICTED_DATA_FILE = "./ES/dev.p4.out"

RU_TRAIN_DATA_FILE = "./RU/train"
RU_TEST_DATA_FILE = "./RU/dev.in"
RU_ACTUAL_DATA_FILE = "./RU/dev.out"
RU_PART1_PREDICTED_DATA_FILE = "./RU/dev.p1.out"
RU_PART2_PREDICTED_DATA_FILE = "./RU/dev.p2.out"
RU_PART3_PREDICTED_DATA_FILE = "./RU/dev.p3.out"
RU_PART4_PREDICTED_DATA_FILE = "./RU/dev.p4.out"

UNK_WORD = "#UNK#"

# %% [markdown]
# # Part 1 - Emission Parameters, UNK Token

# %%
def _preprocess_training_file(file_path):
    with open(file_path, encoding="utf8") as f:
        data = f.read().splitlines()
        data[:] = [x for x in data if x]

    output = []
    for i in data:
        i = i.split(" ")
        if(len(i) > 2):
            i = [" ".join(i[0:len(i)-1]), i[len(i)-1]]
            output.append(i)
        else:
            output.append(i)
        
    return output

def _preprocess_testing_file(path):
    with open(path, encoding="utf8") as f:
        data = f.read().splitlines()

    output = []
    for word in data:
        # if word: # leave the newlines or not?
        output.append(word)

    return output

# %%
def get_emission_using_MLE(training, k = 1):
    tags = {}
    tags_to_word = {}
    emission = {}
    for data in training:
        word, tag = data[0], data[1]
        if tag in tags:
            tags[tag] += 1
        else:
            tags[tag] = 1
        
        tag_to_word = tuple((tag, word))
        if tag_to_word in tags_to_word:
            tags_to_word[tag_to_word] += 1
        else:
            tags_to_word[tag_to_word] = 1

    for key in tags_to_word.keys():
        emission[key] = tags_to_word[key] / (tags[key[0]] + k)
    for key in tags.keys():
        transition = tuple((key, UNK_WORD))
        emission[transition] = k / (tags[key] + k)
    # print(emission)
    return emission

# %%
def get_most_probable_tag(emission):
    highest_prob = {}
    output = {}
    for key, prob in emission.items():
        tag, word = key[0], key[1]
        if word not in highest_prob:
            highest_prob[word] = prob
            output[word] = tag
        else:
            if prob > highest_prob[word]:
                highest_prob[word] = prob
                output[word] = tag
    # print(output)
    return output

# %%
def write_to_predicted_file_part1(predicted_file, test_file, most_probable_tag):
    with open(predicted_file, "w", encoding="utf8") as f:
        for word in test_file:
            if len(word) > 0:
                try:
                    y = most_probable_tag[word]
                except:
                    y = most_probable_tag[UNK_WORD]
                f.write(f"{word} {y}\n")
            else: # leave the newlines??
                f.write("\n")

# %%
# Part 1 code for ES Dataset
ES_train_data = _preprocess_training_file(ES_TRAIN_DATA_FILE)
ES_test_data = _preprocess_testing_file(ES_TEST_DATA_FILE)

ES_emission_parameters = get_emission_using_MLE(ES_train_data)
ES_most_probable_tag = get_most_probable_tag(ES_emission_parameters)
write_to_predicted_file_part1(ES_PART1_PREDICTED_DATA_FILE, ES_test_data, ES_most_probable_tag)

# Part 1 code for RU Dataset
RU_train_data = _preprocess_training_file(RU_TRAIN_DATA_FILE)
RU_test_data = _preprocess_testing_file(RU_TEST_DATA_FILE)

RU_emission_parameters = get_emission_using_MLE(RU_train_data)
RU_most_probable_tag = get_most_probable_tag(RU_emission_parameters)
write_to_predicted_file_part1(RU_PART1_PREDICTED_DATA_FILE, RU_test_data, RU_most_probable_tag)

# %%
from EvalScript.evalResult import get_observed, get_predicted,compare_observed_to_predicted

def evaluateScores(actual_file, predicted_file):
    with open(predicted_file, encoding="utf8") as f:
        predicted = f.read().splitlines()

    with open(actual_file, encoding="utf8") as f:
        actual = f.read().splitlines()
   
    compare_observed_to_predicted(get_observed(actual), get_predicted(predicted))

evaluateScores(ES_ACTUAL_DATA_FILE, ES_PART1_PREDICTED_DATA_FILE)
# Out:
# #Entity in gold data: 255
# #Entity in prediction: 1733
#
# #Correct Entity : 205
# Entity  precision: 0.1183
# Entity  recall: 0.8039
# Entity  F: 0.2062
#
# #Correct Sentiment : 113
# Sentiment  precision: 0.0652
# Sentiment  recall: 0.4431
# Sentiment  F: 0.1137

# %% [markdown]
# # Part 2i - Transition Parameters

# %%
import itertools
def _preprocess_training_file(training_file):
    tags = []
    tags_with_start_stop = []
    words = []

    with open(training_file,"r",encoding="utf8") as f:
        document = f.read().rstrip()
        lines = document.split("\n\n")

        for line in lines:
            tags_list = []
            tags_with_start_stop_list = []
            words_list = []

            for word_tag in line.split("\n"):
                i = word_tag.split(" ")

                if len(i) > 2:
                    i = [" ".join(i[0:len(i)-1]), i[len(i)-1]]

                word, tag = i[0], i[1]
                words_list.append(word)
                tags_list.append(tag)

            tags.append(tags_list)
            tags_with_start_stop_list = ["START"] + tags_list + ["STOP"]
            tags_with_start_stop.append(tags_with_start_stop_list)
            words.append(words_list)
    
    # print(f'tags: {tags[0:3]}')
    # print(f'tags_with_start_stop: {tags_with_start_stop[0:3]}')
    # print(f'words: {words[0:3]}\n')
    return tags, tags_with_start_stop, words

def _preprocess_test_file(testing_file):
    test_words = []

    with open(testing_file,"r",encoding="utf8") as f:
        document = f.read().rstrip()
        lines = document.split("\n\n")

        for line in lines:
            word_list = []
            for word in line.split("\n"):
                word_list.append(word)
            test_words.append(word_list)

    return test_words

# %%
def get_unique_elements(lst):
    return list(set(list(itertools.chain.from_iterable(lst))))

def get_unique_tags(tags):
    tags_unique = get_unique_elements(tags)
    # print(f'tags_unique: {tags_unique}')
    tags_unique.sort()
    # print(f'tags_unique_sorted: {tags_unique}')
    tags_unique_with_start_stop = ["START"] + tags_unique + ["STOP"]
    # print(f'tags_unique_with_start_stop: {tags_unique_with_start_stop}\n')

    return tags_unique, tags_unique_with_start_stop

# %%
def get_transition_pairs(tags):
    transition_pair_count = {}

    for tag in tags:
        #yi-1 and yi tuples
        for tag1, tag2 in zip(tag[:-1], tag[1:]):
            transition_pair = (tag1, tag2)
            if transition_pair in transition_pair_count:
                transition_pair_count[transition_pair] += 1
            else:
                transition_pair_count[transition_pair] = 1

    # print(f'transition_pair_count: {transition_pair_count}\n')
    return transition_pair_count

# %%
def count_y(tag, tags):
    tags_flattened = list(itertools.chain.from_iterable(tags))
    return tags_flattened.count(tag)

# %%
def get_transition_using_MLE(tags_unique_with_start_stop, transition_pair_count,
                          tags_with_start_stop):

    transition = {}
    #create matrix dimensions
    for tag1 in tags_unique_with_start_stop[:-1]:
        transition_row = {}
        for tag2 in tags_unique_with_start_stop[1:]:
            transition_row[tag2] = 0.0
        transition[tag1] = transition_row

    # print(f'transition_params_init: {transition}\n')
    # populate transition parameters with counts
    for tag1, tag2 in transition_pair_count:
        transition[tag1][tag2] += transition_pair_count[(tag1, tag2)]
    
    # print(f'transition_params_with_count: {transition}\n')

    # divide transition_count by count_yi, to get probability
    for tag1, transition_row in transition.items():
        count_yi = count_y(tag1, tags_with_start_stop)

        # words in training set
        for tag2, transition_count in transition_row.items():
            if count_yi == 0:
                transition[tag1][tag2] = 0.0
            else:
                transition[tag1][tag2] = transition_count / count_yi

    # print(f'transition_params_final: {transition}\n')

    return transition

# %%
ES_tags, ES_tags_with_start_stop, ES_train_words = _preprocess_training_file(ES_TRAIN_DATA_FILE)
ES_test_words = _preprocess_test_file(ES_TEST_DATA_FILE)
ES_tags_unique, ES_tags_unique_with_start_stop = get_unique_tags(ES_tags)
ES_transition_pair_count = get_transition_pairs(ES_tags_with_start_stop)
ES_transition_parameters = get_transition_using_MLE(ES_tags_unique_with_start_stop, ES_transition_pair_count, ES_tags_with_start_stop)

RU_tags, RU_tags_with_start_stop, RU_train_words = _preprocess_training_file(RU_TRAIN_DATA_FILE)
RU_test_words = _preprocess_test_file(RU_TEST_DATA_FILE)
RU_tags_unique, RU_tags_unique_with_start_stop = get_unique_tags(RU_tags)
RU_transition_pair_count = get_transition_pairs(RU_tags_with_start_stop)
RU_transition_parameters = get_transition_using_MLE(RU_tags_unique_with_start_stop, RU_transition_pair_count, RU_tags_with_start_stop)

# %% [markdown]
# # Part 2ii - Viterbi Algorithm

# %%
# TODO: Song Gee to write algorithm for Viterbi
import math
import sys

word_output_list = []  # list of tuple(word, predicted_tag) for writing to file
viterbi_values = {}  # key: (n, tag)  value: float 

def generate_viterbi_values(n, current_tag, word_list, tags_unique, emission_params, transmission_params):
    global viterbi_values
    current_max_viterbi_value = -sys.float_info.max  # Smallest negative float
    current_viterbi_values = []
    if n == 0:
        return

    # Recursive call to generate viterbi_values for (n-1, tag)
    for tag in tags_unique:
        if (n-1, tag) not in viterbi_values:
            generate_viterbi_values(n-1, tag, word_list, tags_unique, emission_params, transmission_params)

    # Use viterbi values from n-1 to generate current viterbi value
    for tag in tags_unique:
        # Here, we use a try-except block because our emission parameters only contain emissions which appeared in our datasets
        # Thus, any unobserved emission will throw a KeyError, so we use the emission params with (tag, "#UNK#") instead
        # If transmission_params gives 0, math.log will throw a valueError, thus we catch it and skip the current tag since 0 means we should never consider it
        try:
            try:
                if n == 1:
                    value = math.log(emission_params[(current_tag, word_list[n-1])] * transmission_params[tag][current_tag])  # Log-likelihood for solving numerical underflow
                    # print(f'viterbi_value: {viterbi_values[(n-1, tag)]}, emission_params_value: {emission_params[(current_tag, word_list[n-1])]}, transmission_params_value: {transmission_params[tag][current_tag]}')
                else:
                    value = viterbi_values[(n-1, tag)] + math.log(emission_params[(current_tag, word_list[n-1])] * transmission_params[tag][current_tag])  # Add instead of multiplying using log rules
                    # current_viterbi_values.append(value)
                    # print(current_viterbi_values)
            except KeyError:
                if n == 1:
                    value = math.log(emission_params[(current_tag, UNK_WORD)] * transmission_params[tag][current_tag])
                else:
                    value = viterbi_values[(n-1, tag)] + math.log(emission_params[(current_tag, UNK_WORD)] * transmission_params[tag][current_tag])

        except ValueError:
            continue
        
        # print(f'n: {n}, current_tag: {current_tag}, tag: {tag}, value: {value}')
        current_max_viterbi_value = max(current_max_viterbi_value, value)
        # ? for Part 3, find the 5-th best output sequence 
        # current_viterbi_values.sort(reverse=True)
        # print(current_viterbi_values)
        # current_max_viterbi_value = current_viterbi_values[-1] # take the 5th index??
    
    viterbi_values[(n, current_tag)] = current_max_viterbi_value


# function to kickstart viterbi recursive chain, and add (n+1, STOP) to veterbi_values
def start_viterbi(word_list, tags_unique, emission_params, transmission_params):
    global viterbi_values
    max_final_viterbi_value = -sys.float_info.max

    n = len(word_list)

    # Recursive call to generate viterbi_values for (n, tag)
    for tag in tags_unique:
        generate_viterbi_values(n, tag, word_list, tags_unique, emission_params, transmission_params)

    # Use viterbi values from n to generate viterbi value for (n+1, STOP)
    for tag in tags_unique:
        try:
            value = viterbi_values[(n, tag)] + math.log(transmission_params[tag]['STOP'])
        except ValueError:
            continue
        max_final_viterbi_value = max(max_final_viterbi_value, value)

    viterbi_values[(n+1, 'STOP')] = max_final_viterbi_value


def generate_predictions_viterbi(word_list, tags_unique, emission_params, transmission_params):
    global viterbi_values

    n = len(word_list)

    generated_tag_list = ['' for _ in range(n)]

    # Compute tag for n
    current_best_tag = ''
    current_best_tag_value = -sys.float_info.max

    for tag in tags_unique:
        try:
            value = viterbi_values[(n, tag)] + math.log(transmission_params[tag]['STOP'])
        except ValueError:
            continue
        if value > current_best_tag_value:
            current_best_tag = tag
            current_best_tag_value = value

    # if current_best_tag == '':
    #     current_best_tag = 'O'
    generated_tag_list[n-1] = current_best_tag #! unable to generate best tag sometimes, stuck at ''

    # Generate predictions starting from n-1 going down to 1
    for i in range(n-1, 0, -1):
        current_best_tag = ''
        current_best_tag_value = -sys.float_info.max

        for tag in tags_unique:
            try:
                value = viterbi_values[(i, tag)] + math.log(transmission_params[tag][generated_tag_list[i]])
            except ValueError: #! produces key error: generated_tag_list ["", "B-positive", ...]
                continue
            if value > current_best_tag_value:
                current_best_tag = tag
                current_best_tag_value = value

        generated_tag_list[i-1] = current_best_tag
    
    return generated_tag_list


def write_to_predicted_file_part2(predicted_file, words_list, tags_list):
    assert len(words_list) == len(tags_list)

    with open(predicted_file, "w", encoding="utf8") as f:
        for words, tags in zip(words_list, tags_list):  # Unpack all sentences and list of tags
            assert len(words) == len(tags)
            for word, tag in zip (words, tags):  # Unpack all words and tags
                f.write(f"{word} {tag}\n")
            f.write("\n")

# %%
ES_test_words
ES_train_words
# Out:
# [['disfrutemos',
#   'de',
#   'una',
#   'buenísima',
#   'calidad',
#   'en',
#   'el',
#   'producto',
#   'y',
#   'una',
#   'inmejorable',
#   'relación',
#   'calidad',
#   'precio',
#   '.'],
#  ['Hoy',
#   'he',
#   'ido',
#   'a',
#   'comer',
#   'con',
#   'mia',
#   'padres',
#   'y',
#   'he',
#   'salido',
#   'muy',
#   'defraudado',
#   '.'],
#  ['A', 'mejorar', 'baños', '.'],
#  ['En',
#   'el',
#   'apartado',
#   'de',
#   'ambiente',
#   'todo',
#   'muy',
#   'correcto',
#   ',',
#   'decoración',
#   ',',
#   'música',
#   ',',
#   'ambiente',
#   ',',
#   'etc',
#   '.'],
#  ['La',
#   'excusa',
#   'del',
#   'restaurante',
#   'ha',
#   'sido',
#   'que',
#   'el',
#   'dia',
#   '1',
#   'de',
#   'enero',
#   'siempre',
#   'hay',
#   'mucho',
#   'trabajo',
#   '.'],
#  ['Excelente', '.'],
#  ['Así', 'lo', 'hizo', 'y', 'el', 'resultado', 'fue', 'espectacular', '.'],
#  ['Las',
#   'escaleras',
#   'y',
#   'detalles',
#   'del',
#   'mobiliario',
#   ',',
#   'con',
#   'polvo',
#   'y',
#   'desgastados',
#   ',',
#   'necesitan',
#   'renovación',
#   '.'],
#  ['(',
#   'pense',
#   ')',
#   '.',
#   'El',
#   'resultado',
#   'no',
#   'pudo',
#   'ser',
#   'mas',
#   'decepcionante',
#   '.'],
#  ['Postres',
#   'nada',
#   'atractivos',
#   ',',
#   'la',
#   'misma',
#   'carta',
#   'de',
#   'postres',
#   'de',
#   'los',
#   'últimos',
#   '15',
#   'años',
#   '.'],
#  ['Me', 'gustó', '.'],
#  ['Sinceramente',
#   'lo',
#   'veo',
#   'correcto',
#   'con',
#   'las',
#   'explicaciones',
#   ',',
#   'pero',
#   'para',
#   'mi',
#   'gusto',
#   'es',
#   'una',
#   'barbaridad',
#   'pagar',
#   '170',
#   'euros',
#   'por',
#   'pareja',
#   'por',
#   'lo',
#   'presentado',
#   'contando',
#   'que',
#   'no',
#   'se',
#   'tomaron',
#   'cafes',
#   ',',
#   'y',
#   'lo',
#   'respeto',
#   'ya',
#   'que',
#   'tiene',
#   'una',
#   'estrella',
#   'michelin',
#   ',',
#   'pero',
#   'no',
#   'da',
#   'derecho',
#   'a',
#   'cobrar',
#   'por',
#   'estrella',
#   ',',
#   'lugar',
#   'o',
#   'persona',
#   'con',
#   'la',
#   'que',
#   'has',
#   'aprendido',
#   ',',
#   'la',
#   'cocina',
#   'es',
#   'un',
#   'arte',
#   ',',
#   'un',
#   'gusto',
#   'y',
#   'una',
#   'forma',
#   'de',
#   'presentar',
#   'una',
#   'obra',
#   ',',
#   'asi',
#   'es',
#   'dificil',
#   'que',
#   'mucha',
#   'gente',
#   'pueda',
#   'conocerla',
#   '.'],
#  ['Servicio',
#   'muy',
#   'bueno',
#   ',',
#   'faltan',
#   'platitos',
#   'para',
#   'el',
#   'pan',
#   ',',
#   'pero',
#   'a',
#   'pesar',
#   'de',
#   'eso',
#   ',',
#   'todo',
#   'correcto',
#   '.'],
#  ['Por',
#   'lo',
#   'que',
#   'respecta',
#   'al',
#   'ambiente',
#   'esta',
#   'muy',
#   'bien',
#   'y',
#   'la',
#   'actuación',
#   'de',
#   'un',
#   'drag',
#   'queen',
#   'muy',
#   'entretanida',
#   ',',
#   'no',
#   'descartamos',
#   'volver',
#   'pero',
#   'sólo',
#   'a',
#   'tomar',
#   'una',
#   'copa',
#   'y',
#   'disfrutar',
#   'de',
#   'la',
#   'música',
#   '.'],
#  ['Nos',
#   'dijo',
#   'que',
#   'si',
#   'queríamos',
#   'más',
#   'que',
#   'pidiéramos',
#   ',',
#   'gracias',
#   'de',
#   'nuevo',
#   '.'],
#  ['Variedad', 'si', ',', 'pero', 'en', 'la', 'carta', '.'],
#  ['Vamos',
#   'que',
#   'tampoco',
#   'hace',
#   'falta',
#   'tener',
#   'un',
#   'gran',
#   'Chef',
#   'en',
#   'la',
#   'cocina.La',
#   'factura',
#   'fue',
#   'excesiva',
#   'para',
#   'el',
#   'tipo',
#   'de',
#   'comida',
#   'la',
#   'calidad',
#   'y',
#   'la',
#   'cantidad',
#   '.'],
#  ['Un', 'carta', 'amplia', 'y', 'con', 'mucha', 'variedad', '.'],
#  ['Me',
#   'invitaron',
#   'a',
#   'este',
#   'restaurante',
#   'del',
#   'cual',
#   'desconocia',
#   'su',
#   'existencia',
#   '.'],
#  ['Volveremos', 'seguro'],
#  ['Yo',
#   'recuerdo',
#   'que',
#   'pedí',
#   'chipirones',
#   'guisados',
#   'y',
#   'estaban',
#   'muy',
#   'buenos',
#   ',',
#   'como',
#   'un',
#   'puré',
#   'de',
#   'marisco',
#   'que',
#   'estaba',
#   'riquísimo',
#   '.'],
#  ['Incluido',
#   'algo',
#   'tan',
#   'elemental',
#   'y',
#   'basico',
#   'como',
#   'un',
#   'entrecot',
#   '.'],
#  ['Muy', 'buen', 'restaurante', '.'],
#  ['Cuando',
#   'llegué',
#   ',',
#   'con',
#   'un',
#   'acompañante',
#   ',',
#   'me',
#   'ofrecieron',
#   'la',
#   'carta',
#   ',',
#   'en',
#   'vez',
#   'del',
#   'Menú',
#   '.'],
#  ['DE', 'VERGÜENZA', '!', '!', '!'],
#  ['Si',
#   'tienes',
#   'cuidado',
#   'con',
#   'lo',
#   'que',
#   'pides',
#   'puedes',
#   'comer',
#   'muy',
#   'bien',
#   'sin',
#   'dejarte',
#   'la',
#   'cartera',
#   '.'],
#  ['Alagarmos', 'la', 'cena', 'hasta', 'las', 'tres', 'tomando', 'copas', '.'],
#  ['Ayer', 'estuvimos', 'en', 'el', 'Aragonia', 'para', 'comer', '.'],
#  ['Te',
#   'gustará',
#   'y',
#   'si',
#   'lo',
#   'que',
#   'quieres',
#   'es',
#   'quedar',
#   'bien',
#   ',',
#   'lo',
#   'conseguiras',
#   '.'],
#  ['Era',
#   'jueves',
#   'por',
#   'la',
#   'noche',
#   'y',
#   'eramos',
#   'los',
#   'unicos',
#   'clientes',
#   'del',
#   'restaurante',
#   '.'],
#  ['Quería', 'hablar', 'de', 'la', 'iluminación', 'del', 'local', '.'],
#  ['Coincido', 'con', 'los', 'Datos', 'de', 'la', 'ficha', '.'],
#  ['Parecía',
#   'una',
#   'apuesta',
#   'sobre',
#   'seguro',
#   ',',
#   '“',
#   'único',
#   'restaurante',
#   'de',
#   'Zaragoza',
#   'con',
#   'Estrella',
#   'Michelín',
#   '”',
#   '!',
#   '!'],
#  ['9.5'],
#  ['No', 'fué', 'así', '.'],
#  ['En', 'el', 'vale', 'descuento', 'no', 'pone', 'nada', 'de', 'esto', '.'],
#  ['Calidad',
#   ',',
#   'profesionalidad',
#   'y',
#   'precio',
#   'acorde',
#   'con',
#   'la',
#   'oferta',
#   '.'],
#  ['Comida',
#   'excelente',
#   'asi',
#   'como',
#   'su',
#   'el',
#   'servicio',
#   'de',
#   'camarero',
#   '.'],
#  ['Pedro',
#   ':',
#   'Me',
#   'temo',
#   'que',
#   'no',
#   'has',
#   'probado',
#   'los',
#   'cavas',
#   'Aragones',
#   'adecuados',
#   'como',
#   'el',
#   'Cava',
#   'Monasterio',
#   'de',
#   'Veruela',
#   'o',
#   'el',
#   'Reinante',
#   ',',
#   'o',
#   'el',
#   'Real',
#   'de',
#   'Aragón',
#   ',',
#   '…',
#   'cualquier',
#   'de',
#   'estos',
#   'relación',
#   'calidad',
#   'precio',
#   'está',
#   'por',
#   'encima',
#   'de',
#   'los',
#   'Catalanes',
#   '.'],
#  ['Restaurante',
#   'bien',
#   'decorado',
#   ',',
#   'aunque',
#   'con',
#   'espacios',
#   'reducidos',
#   '.'],
#  ['Para',
#   'empezar',
#   'el',
#   'plato',
#   'y',
#   'la',
#   'servilleta',
#   'tenían',
#   'carbonilla',
#   'negra',
#   '.'],
#  ['Muy',
#   'caro',
#   'por',
#   'la',
#   'comida',
#   'que',
#   'ofrecen',
#   ',',
#   'he',
#   'comido',
#   'igual',
#   'o',
#   'mejor',
#   'en',
#   'La',
#   'Flauta',
#   ',',
#   'El',
#   'Asador',
#   'de',
#   'Aranda',
#   ',',
#   'etc',
#   '.'],
#  ['Recomendable', '.'],
#  ['Para',
#   'beber',
#   ',',
#   'agua',
#   'con',
#   'gas',
#   'y',
#   'sin',
#   'gas',
#   'y',
#   'una',
#   'botella',
#   'de',
#   'Gran',
#   'Vos',
#   '2007',
#   'de',
#   'Viñas',
#   'del',
#   'Vero',
#   '.'],
#  ['Yo', 'no', 'voy', 'a', 'volver', '.'],
#  ['Pero',
#   'pedimos',
#   'que',
#   'nos',
#   'cambiasen',
#   'y',
#   'a',
#   'partir',
#   'de',
#   'ahí',
#   'todo',
#   'fenomenal',
#   '.'],
#  ['No',
#   'puedo',
#   'disfrutar',
#   'más',
#   'en',
#   'Maur',
#   '!',
#   'La',
#   'calidad',
#   'de',
#   'sus',
#   'carnes',
#   'y',
#   'verduras',
#   'a',
#   'la',
#   'brasa',
#   'es',
#   'impresionante',
#   '!'],
#  ['Muy', 'buen', 'sabor', ',', 'en', 'cualquier', 'caso', '.'],
#  ['Amo', 'el', 'pescado', 'en', 'Salamanca', '!'],
#  ['Hemos',
#   'comido',
#   'estupendamente',
#   'con',
#   'unos',
#   'platos',
#   'exquisitos',
#   'con',
#   'una',
#   'elaboracion',
#   'esmerada',
#   ',',
#   'el',
#   'servicio',
#   'en',
#   'su',
#   'justa',
#   'medida',
#   'y',
#   'el',
#   'personal',
#   'de',
#   'cocina',
#   ';',
#   'los',
#   'autores',
#   'de',
#   'las',
#   'delicias',
#   'que',
#   'salen',
#   'a',
#   'la',
#   'mesa',
#   ':',
#   'Una',
#   'ovación',
#   'cerrada',
#   ',',
#   'la',
#   'vuelta',
#   'al',
#   'ruedo',
#   'y',
#   'las',
#   'dos',
#   'orejas',
#   '.'],
#  ['El',
#   'magret',
#   'nada',
#   'fino',
#   ',',
#   'tenía',
#   'increíblemente',
#   'los',
#   'pelitos',
#   'del',
#   'pato',
#   '.'],
#  ['Estamos',
#   'hablando',
#   'de',
#   'un',
#   'sitio',
#   'muy',
#   'fino',
#   'situado',
#   'en',
#   'el',
#   'cogollo',
#   'barcelonés',
#   ',',
#   'por',
#   'tanto',
#   ',',
#   'entiendo',
#   ',',
#   'que',
#   'se',
#   'tiene',
#   'que',
#   'reflejar',
#   'en',
#   'el',
#   'precio',
#   '.'],
#  ['Luego', 'Salomillo', '.'],
#  ['Qué',
#   'pena',
#   'que',
#   'no',
#   'sepan',
#   'diferenciar',
#   'entre',
#   'un',
#   'pescado',
#   'cocinado',
#   '“',
#   'en',
#   'su',
#   'punto',
#   '”',
#   'y',
#   'un',
#   'pescado',
#   'directamente',
#   'crudo',
#   ',',
#   'donde',
#   'la',
#   'carne',
#   'no',
#   'se',
#   'desprende',
#   'de',
#   'la',
#   'espina',
#   'por',
#   'falta',
#   'de',
#   'calor',
#   'y',
#   'cocción',
#   '.'],
#  ['La',
#   'atención',
#   'de',
#   'todo',
#   'el',
#   'personal',
#   'fue',
#   'muy',
#   'buena',
#   'y',
#   'el',
#   'local',
#   'acogedor',
#   '.'],
#  ['Sitio',
#   'muy',
#   'recomendable',
#   'por',
#   'su',
#   'comida',
#   'y',
#   'por',
#   'lo',
#   'bonito',
#   'que',
#   'es',
#   'el',
#   'restaurante',
#   '.'],
#  ['Totalmente',
#   'recomendable',
#   'para',
#   'cualquier',
#   'evento',
#   ':',
#   'familia',
#   ',',
#   'amigos',
#   'y',
#   'pareja'],
#  ['El', 'camarero', 'ni', 'idea', '.'],
#  ['No',
#   'es',
#   'acogedor',
#   ',',
#   'muy',
#   'frio',
#   'emocionalmente',
#   'y',
#   'nada',
#   'intimo',
#   '.'],
#  ['Pues',
#   'Pedro',
#   ',',
#   'hay',
#   'que',
#   'tener',
#   'criterio',
#   'propio',
#   ',',
#   'valorar',
#   'las',
#   'recomendaciones',
#   'en',
#   'su',
#   'justa',
#   'medida',
#   ',',
#   'como',
#   'lo',
#   'que',
#   'son',
#   ',',
#   'impresiones',
#   'personales',
#   ',',
#   'y',
#   'no',
#   'tener',
#   'miedo',
#   'a',
#   'probar',
#   ',',
#   'e',
#   'incluso',
#   'que',
#   'te',
#   'defraude',
#   '.'],
#  ['Un',
#   'restaurante',
#   'al',
#   'que',
#   'yo',
#   'calificaría',
#   'como',
#   'valor',
#   'seguro',
#   'en',
#   'cuanto',
#   'a',
#   'la',
#   'cocina',
#   'pero',
#   'mejorable',
#   'en',
#   'servicio',
#   'aunque',
#   'sin',
#   'ser',
#   'desastroso',
#   'ni',
#   'mucho',
#   'menos',
#   '.'],
#  ['Los',
#   'entrantes',
#   'bién',
#   ',',
#   'pero',
#   'el',
#   'arroz',
#   'caldoso',
#   'lo',
#   'he',
#   'devuelto',
#   'porque',
#   'no',
#   'tenia',
#   'sabor',
#   'a',
#   'nada',
#   '.'],
#  ['Muy', 'bien', '.'],
#  ['Segunda',
#   'Fiesta',
#   'de',
#   'Comunión',
#   'que',
#   'me',
#   'toca',
#   'pasar',
#   'en',
#   'la',
#   'Junquera',
#   '.'],
#  ['Fui',
#   'con',
#   'mi',
#   'mujer',
#   'y',
#   'mis',
#   'suegros',
#   'y',
#   'todos',
#   'quedaron',
#   'encantados',
#   ':',
#   'servicio',
#   ',',
#   'velocidad',
#   ',',
#   'puntos',
#   'de',
#   'cocción',
#   ',',
#   'raciones',
#   ',',
#   'calidad',
#   '/',
#   'precio',
#   ',',
#   'Solo',
#   'dos',
#   'peros',
#   ':',
#   'el',
#   'vino',
#   'de',
#   'la',
#   'casa',
#   'tenía',
#   'un',
#   'punto',
#   'de',
#   'rancidumbre',
#   'y',
#   'que',
#   'nos',
#   'podrían',
#   'haber',
#   'puesto',
#   'en',
#   'un',
#   'punto',
#   'más',
#   'céntrico',
#   'del',
#   'salón',
#   '.'],
#  ['Servicio', 'bueno', '.'],
#  ['Luego', 'hemos', 'ido', 'más', 'veces', '.'],
#  ['Exquisitas', 'las', 'ensaladas', 'y', 'la', 'carne', '.'],
#  ['Confío',
#   'en',
#   'él',
#   'desde',
#   'que',
#   'estaba',
#   'en',
#   'la',
#   'C',
#   '/',
#   'Muntaner',
#   '.'],
#  ['El', 'cabrito', ',', 'genial', '.'],
#  ['No', 'lo', 'recomiendo', 'para', 'nada'],
#  ['soy',
#   'quién',
#   'advirtió',
#   'a',
#   'luis',
#   'de',
#   'éste',
#   'comentario',
#   'el',
#   'lunes',
#   '.'],
#  ['No', 'lo', 'aconsejo', 'para', 'todo', 'tipo', 'de', 'comensales', '…'],
#  ['Sin', 'duda', 'volveremos', '.'],
#  ['El',
#   'restaurante',
#   'es',
#   'muy',
#   'bonito',
#   ',',
#   'el',
#   'ambiente',
#   'es',
#   'agradable',
#   'y',
#   'la',
#   'decoración',
#   'excepcional',
#   'así',
#   'somo',
#   'el',
#   'servicio',
#   'que',
#   'fue',
#   'muy',
#   'amable',
#   'en',
#   'todo',
#   'momento',
#   '.'],
#  ['Tanto',
#   'el',
#   'ambiente',
#   'del',
#   'lugar',
#   'como',
#   'la',
#   'atencion',
#   'de',
#   'los',
#   'camareros',
#   'fue',
#   'impoluta',
#   ',',
#   'asi',
#   'que',
#   'salimos',
#   'con',
#   'una',
#   'magnifica',
#   'sensacion',
#   '.'],
#  ['Por', 'el', 'resto', 'todo', 'fantástico', '.'],
#  ['Ambiente',
#   'muy',
#   'agradable',
#   ',',
#   'buen',
#   'servicio',
#   'y',
#   'buena',
#   'comida',
#   '.'],
#  ['Todo', 'muy', 'bien', '!'],
#  ['Pedimos',
#   'un',
#   'risotto',
#   '(',
#   'acceptable',
#   ')',
#   'y',
#   'una',
#   'pizza',
#   '(',
#   'muy',
#   'mejorable',
#   ')',
#   'y',
#   'postres',
#   '(',
#   'lo',
#   'mejor',
#   ')',
#   '.'],
#  ['Lamento',
#   'ser',
#   'yo',
#   'quien',
#   'os',
#   'diga',
#   'que',
#   'los',
#   'combinados',
#   'se',
#   'preparan',
#   'en',
#   'la',
#   'mesa',
#   ',',
#   'de',
#   'la',
#   'cocina',
#   'sale',
#   'el',
#   'vaso',
#   '(',
#   'o',
#   'lo',
#   'que',
#   'sea',
#   ',',
#   'en',
#   'este',
#   'caso',
#   'copa',
#   ')',
#   'con',
#   'el',
#   'hielo',
#   'y',
#   'la',
#   'rodajita',
#   'de',
#   'limon',
#   ',',
#   'lima',
#   'o',
#   'lo',
#   'que',
#   'sea',
#   'y',
#   'la',
#   'ginebra',
#   'se',
#   'sirve',
#   'delante',
#   'del',
#   'cliente',
#   'al',
#   'igual',
#   'que',
#   'la',
#   'tonica',
#   ',',
#   'no',
#   'es',
#   'por',
#   'suspicacia',
#   'es',
#   'por',
#   'practica',
#   'habitual',
#   '(',
#   'no',
#   'se',
#   'me',
#   'pasa',
#   'por',
#   'la',
#   'mente',
#   'dudar',
#   'de',
#   'los',
#   'ingredientes',
#   'pero',
#   'no',
#   'queda',
#   'bien',
#   ')',
#   '.'],
#  ['Por',
#   'supuesto',
#   ',',
#   'como',
#   'era',
#   'un',
#   'momento',
#   'especial',
#   ',',
#   'no',
#   'quise',
#   'montar',
#   'ningún',
#   'circo',
#   ',',
#   'ni',
#   'pedir',
#   'el',
#   'libro',
#   'de',
#   'reclamaciones',
#   ',',
#   'pero',
#   'la',
#   'sensación',
#   'con',
#   'la',
#   'que',
#   'salí',
#   'de',
#   'ese',
#   'restaurante',
#   'no',
#   'fue',
#   'buena',
#   ',',
#   'me',
#   'sentí',
#   'estafada.En',
#   'fin',
#   ',',
#   'que',
#   'no',
#   'lo',
#   'aconsejo',
#   'para',
#   'nada',
#   ',',
#   'el',
#   'sitio',
#   'es',
#   'bonito',
#   ',',
#   'la',
#   'comida',
#   'buena',
#   ',',
#   'pero',
#   'excesivamente',
#   'caro',
#   'para',
#   'lo',
#   'que',
#   'realmente',
#   'es',
#   ',',
#   'y',
#   'por',
#   'supuesto',
#   ',',
#   'no',
#   'animo',
#   'a',
#   'nadie',
#   'a',
#   'que',
#   'compre',
#   'cupones',
#   'para',
#   'comer',
#   'allí',
#   ',',
#   'puesto',
#   'que',
#   'se',
#   'arriesgan',
#   'a',
#   'que',
#   'les',
#   'sirvan',
#   'lo',
#   'que',
#   'ellos',
#   'consideren',
#   'en',
#   'ese',
#   'momento',
#   ',',
#   'independientemente',
#   'de',
#   'lo',
#   'que',
#   'hayas',
#   'pagado',
#   'con',
#   'anterioridad',
#   '.'],
#  ['Este',
#   'era',
#   'el',
#   'menú',
#   'que',
#   'aparecía',
#   'en',
#   'el',
#   'cupón',
#   ',',
#   'la',
#   'verdad',
#   'que',
#   'tenía',
#   'muy',
#   'buena',
#   'pinta',
#   '…',
#   ':'],
#  ['El', 'servicio', 'fue', 'atento', '.'],
#  ['Buena', 'calidad', 'y', 'correcta', 'cantidad', '.'],
#  ['Estuvimos',
#   'muy',
#   'bién',
#   'servidos',
#   'y',
#   'la',
#   'comida',
#   'estuvo',
#   'genial',
#   '.'],
#  ['Repito',
#   'cada',
#   'vez',
#   'que',
#   'puedo',
#   ',',
#   'con',
#   'la',
#   'familia',
#   'o',
#   'con',
#   'la',
#   'empresa',
#   '.'],
#  ['restaurante',
#   'correcto',
#   'de',
#   'la',
#   'linea',
#   'de',
#   'los',
#   'demas',
#   'olive',
#   ',',
#   'etc',
#   '.'],
#  ['Todo',
#   'cuidado',
#   'y',
#   'aprobado',
#   'por',
#   'el',
#   'ojo',
#   'minucioso',
#   ',',
#   'elegante',
#   ',',
#   'trabajador',
#   'incansable',
#   ',',
#   'y',
#   'profesional',
#   'de',
#   'su',
#   'director',
#   'de',
#   'orquesta',
#   ';',
#   'don',
#   'Ramón',
#   'Ferreira',
#   '.'],
#  ['Es', 'un', 'Restaurante', 'muy', 'recomendable', '.'],
#  ['Festival', 'de', 'congelado', 'aceitoso', 'y', 'arroz', 'pasado', '.'],
#  ['Excelente', 'ubicación', 'e', 'iluminación', '.'],
#  ['Sobre',
#   'el',
#   'tema',
#   'del',
#   'humo',
#   'no',
#   'puedo',
#   'opinar',
#   'ya',
#   'que',
#   'nunca',
#   'he',
#   'estado',
#   'con',
#   'el',
#   'restaurante',
#   'lleno',
#   ',',
#   'siempre',
#   'que',
#   'he',
#   'ido',
#   'estaba',
#   'semilleno',
#   'y',
#   'no',
#   'había',
#   'ningún',
#   'problema',
#   'de',
#   'humo',
#   '.'],
#  ['La',
#   'atención',
#   'esmerada',
#   'y',
#   'la',
#   'calidad',
#   'de',
#   'la',
#   'comida',
#   'excelente',
#   '.'],
#  ['Siempre',
#   'es',
#   'excelso',
#   'en',
#   'su',
#   'comida',
#   'y',
#   'perfecto',
#   'en',
#   'su',
#   'servicio',
#   '.'],
#  ['Hacia',
#   'mucho',
#   'tiempo',
#   'que',
#   'quería',
#   'ir',
#   'a',
#   'este',
#   'restaurante',
#   'por',
#   'las',
#   'buenas',
#   'referencias',
#   'que',
#   'había',
#   'recibido',
#   'y',
#   'no',
#   'me',
#   'defraudó',
#   '.'],
#  ['Hemos', 'comido', 'fenomenal', '.'],
#  ['El',
#   'ambiente',
#   'es',
#   'agradable',
#   'y',
#   'el',
#   'servicio',
#   'rápido',
#   'y',
#   'amable',
#   '.'],
#  ['Estuve',
#   'cenando',
#   'ayer',
#   'por',
#   'la',
#   'noche',
#   ',',
#   'tenía',
#   'ganas',
#   'de',
#   'probarlo',
#   ',',
#   'la',
#   'verdad',
#   'es',
#   'que',
#   'la',
#   'comida',
#   'estaba',
#   'buena',
#   ',',
#   'de',
#   'hecho',
#   'felicitamos',
#   'al',
#   'cocinero',
#   '(',
#   'creo',
#   'que',
#   'se',
#   'llamaba',
#   'César',
#   ')',
#   '.'],
#  ['El', 'precio', 'es', 'elevado', 'pero', 'lo', 'vale', '.'],
#  ['Creo',
#   'q',
#   'cuando',
#   'se',
#   'va',
#   'a',
#   'un',
#   'restaurante',
#   'de',
#   'ese',
#   'nivel',
#   'y',
#   'hay',
#   'un',
#   'cambio',
#   'en',
#   'el',
#   'menú',
#   ',',
#   'se',
#   'debe',
#   'advertir',
#   'al',
#   'presentar',
#   'la',
#   'carta',
#   ',',
#   'y',
#   'q',
#   'si',
#   'se',
#   'hace',
#   'después',
#   ',',
#   'se',
#   'deben',
#   'dar',
#   'opciones',
#   'para',
#   'cambiar',
#   'de',
#   'plato',
#   'si',
#   'a',
#   'algún',
#   'comensal',
#   'no',
#   'le',
#   'gusta',
#   '.'],
#  ['Perfecto', '.'],
#  ['La', 'cocina', 'deliciosa', '.'],
#  ['Nos', 'fuimos', 'en', 'el', 'descanso', '.'],
#  ['En',
#   'general',
#   'a',
#   'un',
#   'gran',
#   'nivel',
#   'todos',
#   'los',
#   'platos',
#   'que',
#   'fueron',
#   'individuales',
#   'así',
#   'que',
#   'da',
#   'igual',
#   'el',
#   'numero',
#   'de',
#   'personas',
#   'de',
#   'la',
#   'mesa',
#   'los',
#   'entrantes',
#   'serán',
#   'los',
#   'mismos',
#   '.'],
#  ['Por',
#   'otro',
#   'lado',
#   'me',
#   'alegro',
#   'de',
#   'coincidir',
#   'con',
#   'usted',
#   'en',
#   'los',
#   'gustos',
#   ',',
#   'no',
#   'tanto',
#   'de',
#   'que',
#   'ambos',
#   'saliéramos',
#   'decepcionados',
#   'de',
#   'este',
#   'restaurante',
#   ',',
#   'porque',
#   'supongo',
#   'que',
#   'a',
#   'usted',
#   ',',
#   'igual',
#   'que',
#   'a',
#   'mi',
#   ',',
#   'nos',
#   'hubiera',
#   'gustado',
#   'salir',
#   'contentísimos',
#   'del',
#   'Bal',
#   'd',
#   '’',
#   'Onsera',
#   ',',
#   'recomendarlo',
#   'por',
#   'doquier',
#   'y',
#   'no',
#   'tener',
#   'la',
#   'sensación',
#   'de',
#   'haber',
#   'perdido',
#   'tiempo',
#   'y',
#   'dinero',
#   ',',
#   'al',
#   'menos',
#   'yo',
#   '.'],
#  ['se',
#   'come',
#   'muy',
#   'bien',
#   ',',
#   'hace',
#   'años',
#   'que',
#   'vamos',
#   'y',
#   'siempre',
#   'nos',
#   'ha',
#   'gustado',
#   'su',
#   'cocina',
#   ',',
#   'muy',
#   'atentos',
#   '.'],
#  ['No', 'es', 'un', 'chollo', 'en', 'cuanto', 'a', 'precio', '.'],
#  ['Mas',
#   'que',
#   'otro',
#   '“',
#   'cachirulo',
#   '”',
#   'sugiero',
#   'al',
#   'autor',
#   'de',
#   'este',
#   'blog',
#   ',',
#   'la',
#   'marca',
#   '“',
#   'siempre',
#   'aciertas',
#   '”',
#   '.'],
#  ['Fantástico', '.'],
#  ['Servicio',
#   'excelente',
#   'y',
#   'al',
#   'detalle',
#   'junto',
#   'a',
#   'un',
#   'buen',
#   'equilibrio',
#   'entre',
#   'calidad-precio',
#   '.'],
#  ['Gracias',
#   'por',
#   'tu',
#   'crónica',
#   ',',
#   'me',
#   'ha',
#   'sido',
#   'de',
#   'gran',
#   'ayuda',
#   'para',
#   'decidir',
#   'a',
#   'donde',
#   'NO',
#   'ir',
#   'a',
#   'celebrar',
#   'una',
#   'cena',
#   'especial',
#   ',',
#   'dejaré',
#   'mi',
#   'sitio',
#   'para',
#   'los',
#   'críticos',
#   'gastronómicos',
#   'experimentados',
#   '.'],
#  ['Fabuloso',
#   'comienzo',
#   'de',
#   'año',
#   'con',
#   'una',
#   'comida',
#   'estupenda',
#   'y',
#   'una',
#   'estancia',
#   'genial',
#   'tanto',
#   'por',
#   'el',
#   'ambiente',
#   'como',
#   'por',
#   'el',
#   'agradable',
#   'trato',
#   'recibido',
#   ',',
#   'como',
#   'en',
#   'anteriores',
#   'veces',
#   ',',
#   'repetiremos',
#   '.'],
#  ['Respecto',
#   'a',
#   'lo',
#   'de',
#   'la',
#   '“',
#   'cocina',
#   'molecular',
#   '”',
#   ',',
#   'no',
#   'te',
#   'preocupes',
#   ':',
#   'a',
#   'mí',
#   'me',
#   'gusta',
#   'mucho',
#   'la',
#   '“',
#   'cocina',
#   'molecular',
#   '”',
#   ',',
#   'pero',
#   'la',
#   'de',
#   'Colette',
#   'no',
#   'lo',
#   'es',
#   '.'],
#  ['buen', 'servicio', 'menu', 'excelente'],
#  ['Pero',
#   'aún',
#   'así',
#   ',',
#   'si',
#   'la',
#   'comida',
#   'hubiese',
#   'triunfado',
#   ',',
#   'nos',
#   'hubiese',
#   'dado',
#   'igual',
#   '.'],
#  ['MUY', 'RECOMENDABLE'],
#  ['Un', 'buen', 'restaurante', '.'],
#  ['Reserva', 'calçotada', '.'],
#  ['Hola', '.'],
#  ['Creo',
#   'que',
#   'si',
#   'espaciaran',
#   'un',
#   'poco',
#   'las',
#   'mesas',
#   'y',
#   'cambiaran',
#   'la',
#   'iluminación',
#   'por',
#   'algo',
#   'mas',
#   'calido',
#   'el',
#   'local',
#   'ganaría',
#   'mucho',
#   ',',
#   'pero',
#   'tal',
#   'vez',
#   'este',
#   'restaurante',
#   'no',
#   'este',
#   'dirigido',
#   'al',
#   'publico',
#   'que',
#   'se',
#   'fije',
#   'en',
#   'los',
#   'detalles',
#   'y',
#   'quiera',
#   'estar',
#   'a',
#   'gusto',
#   'cuando',
#   'come',
#   '.'],
#  ['Comimos',
#   'en',
#   'el',
#   'comedor',
#   'del',
#   'balneario',
#   'que',
#   'por',
#   'cierto',
#   'es',
#   'de',
#   'felicitar',
#   'la',
#   'comida',
#   ',',
#   'que',
#   'bien',
#   'comimos',
#   '.'],
#  ['¿', 'La', 'mesa', 'tenía', 'que', 'estar', 'reservada', '?', '.'],
#  ['Buen',
#   'ambiente',
#   ',',
#   'la',
#   'comida',
#   'genial',
#   ',',
#   'bien',
#   'situado',
#   '.'],
#  ['La',
#   'comida',
#   'muy',
#   'bien',
#   ',',
#   'estupenda',
#   ',',
#   'servicio',
#   'bueno',
#   ',',
#   'un',
#   'poco',
#   'lentos',
#   '.'],
#  ['La',
#   'ultima',
#   'vez',
#   'estuve',
#   'en',
#   'enero',
#   'con',
#   'un',
#   'compromiso',
#   'laboral',
#   'y',
#   'en',
#   'estos',
#   'casos',
#   'siempre',
#   'voy',
#   'alli',
#   'porque',
#   'es',
#   'apuesta',
#   'segura',
#   '.'],
#  ['El',
#   'motivo',
#   'es',
#   'que',
#   'fuisteis',
#   'dos',
#   'personas',
#   'a',
#   'tomar',
#   'el',
#   'menú',
#   'de',
#   'grupos',
#   'y',
#   'eso',
#   'no',
#   'es',
#   'posible',
#   ',',
#   'para',
#   'dos',
#   'personas',
#   'está',
#   'disponible',
#   'el',
#   'de',
#   '32',
#   'y',
#   'el',
#   'de',
#   '36',
#   ',',
#   'y',
#   'os',
#   'sirvieron',
#   'y',
#   'disfrutásteis',
#   'el',
#   'de',
#   '32',
#   ',',
#   'y',
#   'me',
#   'alegro',
#   'mucho',
#   'que',
#   'os',
#   'gustara',
#   ',',
#   'eso',
#   'es',
#   'lo',
#   'que',
#   'pasó',
#   ',',
#   'lo',
#   'importante',
#   'en',
#   'cualquier',
#   'caso',
#   'es',
#   'que',
#   'salierais',
#   'contentos',
#   '.'],
#  ['Un',
#   'restaurante',
#   'de',
#   'ambiente',
#   'moderno',
#   'donde',
#   'la',
#   'comida',
#   'está',
#   'en',
#   'su',
#   'ounto',
#   'y',
#   'el',
#   'trato',
#   'es',
#   'muy',
#   'amable',
#   '.'],
#  ['Pero',
#   'también',
#   'creo',
#   'que',
#   'este',
#   'reconocimiento',
#   'debería',
#   'hacer',
#   'reflexionar',
#   'a',
#   'aquellas',
#   'voces',
#   'o',
#   'comentarios',
#   'críticos',
#   ',',
#   'que',
#   'también',
#   'se',
#   'pueden',
#   'equivocar.Zaragozana'],
#  ['Sí', 'pero', 'no', ',', 'sería', 'el', 'resumen', 'final', '.'],
#  ['Hicimos',
#   'una',
#   'reserva',
#   'para',
#   '11',
#   'y',
#   'la',
#   'verdad',
#   'es',
#   'que',
#   'todo',
#   'muy',
#   'correcto',
#   '.'],
#  ['Felicitar', 'desde', 'aqii', 'a', 'la', 'direccion', '.'],
#  ['Había',
#   'estado',
#   'en',
#   'diversas',
#   'cenas',
#   'de',
#   'grupo',
#   'en',
#   '2004',
#   'y',
#   '2005',
#   'y',
#   'nada',
#   'comparable',
#   'a',
#   'lo',
#   'que',
#   'me',
#   'encontré',
#   'en',
#   'Enero',
#   'de',
#   '2009',
#   ':',
#   'una',
#   'atención',
#   'pésima',
#   ',',
#   'una',
#   'comida',
#   'justita',
#   'y',
#   'un',
#   'precio',
#   'caro',
#   'para',
#   'lo',
#   'recibido',
#   '.'],
#  ['Elegimos',
#   'la',
#   'opcion',
#   'del',
#   'menu',
#   'cerrado',
#   'más',
#   'economico',
#   'para',
#   '4',
#   'personas',
#   'y',
#   'decir',
#   'que',
#   'la',
#   'calidad-precio',
#   'de',
#   'lo',
#   'que',
#   'obtuvimos',
#   'fue',
#   'deficiente.El',
#   'menu',
#   'consistió',
#   'en',
#   'un',
#   'aperitivo',
#   'de',
#   'crema',
#   'de',
#   'anochas',
#   'que',
#   'estaba',
#   'realmente',
#   'conseguido',
#   '.'],
#  ['Muy',
#   'buena',
#   'descripción',
#   'Pedro',
#   ',',
#   'no',
#   'he',
#   'estado',
#   'todavía',
#   'en',
#   'el',
#   'restaurante',
#   'Colette',
#   ',',
#   'he',
#   'leído',
#   'algunas',
#   'opiniones',
#   'negativas',
#   'y',
#   'otras',
#   'positivas',
#   ',',
#   'pero',
#   'desde',
#   'luego',
#   'por',
#   'lo',
#   'que',
#   'comentas',
#   'es',
#   'muy',
#   'recomendable',
#   'su',
#   'cocina',
#   '.'],
#  ['Servicio',
#   'atento',
#   'en',
#   'su',
#   'cometido',
#   ',',
#   'quizas',
#   'demasiado',
#   'rápido',
#   'en',
#   'atendernos',
#   ',',
#   'no',
#   'habíamos',
#   'decidido',
#   'aún',
#   'la',
#   '"',
#   'petición',
#   '"',
#   'que',
#   'ya',
#   'estaba',
#   'esperando',
#   'nustra',
#   'decisión',
#   '.'],
#  ['Un',
#   'lugar',
#   'hermoso',
#   'su',
#   'vista',
#   'espectacular',
#   ',',
#   'su',
#   'carta',
#   'muy',
#   'cara',
#   'en',
#   'precios',
#   ',',
#   'no',
#   'recomendable',
#   'para',
#   'lo',
#   'que',
#   'se',
#   'come',
#   ',',
#   'su',
#   'maitre',
#   'muy',
#   'mal',
#   'encarado',
#   ',',
#   'su',
#   'camarero',
#   'muy',
#   'distraido',
#   ',',
#   'mucho',
#   'ruido',
#   '.'],
#  ['Lo',
#   'unico',
#   'que',
#   'puedo',
#   'decir',
#   'es',
#   'que',
#   'la',
#   'calidad',
#   'de',
#   'lo',
#   'que',
#   'comimos',
#   'fue',
#   'estupenda',
#   ',',
#   'pero',
#   'nos',
#   'sorprendio',
#   'la',
#   'cantidad',
#   ',',
#   'que',
#   'era',
#   'mas',
#   'bien',
#   'escasa',
#   '.'],
#  ['Me',
#   'encantó',
#   'el',
#   'filete',
#   'de',
#   'vedella',
#   'al',
#   'foie',
#   ',',
#   'en',
#   'general',
#   'le',
#   'doy',
#   'una',
#   'puntuación',
#   'de',
#   '9',
#   '.'],
#  ['La',
#   'atención',
#   'no',
#   'es',
#   'mala',
#   ',',
#   'pero',
#   'si',
#   'se',
#   'reserva',
#   ',',
#   'no',
#   'se',
#   'debe',
#   'montar',
#   'la',
#   'mesa',
#   'a',
#   'parte',
#   'si',
#   'se',
#   'ha',
#   'dado',
#   'cuenta',
#   'que',
#   'la',
#   'sala',
#   'comedor',
#   'esta',
#   'llena',
#   ',',
#   'si',
#   'no',
#   'para',
#   'que',
#   'reservar',
#   '?'],
#  ['Por',
#   'tercera',
#   'vez',
#   'le',
#   'pido',
#   'la',
#   'salsa',
#   'y',
#   'entonces',
#   'se',
#   'digna',
#   'contestarme',
#   'que',
#   'no',
#   'tienen',
#   'y',
#   'la',
#   'han',
#   'de',
#   'hacer',
#   'al',
#   'momento',
#   ',',
#   'a',
#   'lo',
#   'que',
#   'le',
#   'contesto',
#   'que',
#   'me',
#   'lo',
#   'podría',
#   'haber',
#   'explicado',
#   'desde',
#   'un',
#   'principio',
#   'y',
#   'yo',
#   'hubiera',
#   'decidido',
#   'si',
#   'escogía',
#   'el',
#   'plato',
#   'o',
#   'no',
#   'porque',
#   'una',
#   'vez',
#   'comido',
#   'ya',
#   'no',
#   'tenía',
#   'sentido',
#   'que',
#   'la',
#   'trajesen',
#   '.'],
#  ['Escriba', 'aquí', 'su', 'comentario', '…'],
#  [';',
#   'por',
#   'la',
#   'tarde',
#   'hicimos',
#   'tratamientos',
#   'y',
#   'masajes',
#   'y',
#   'disfrutamos',
#   'mucho',
#   'de',
#   'la',
#   'piscina',
#   'exterior',
#   'y',
#   'el',
#   'solarium',
#   '.'],
#  ['Increíble', '.'],
#  ['una', 'persona', 'cabal', 'y', 'honesta', '.'],
#  ['Lo',
#   'temas',
#   'todo',
#   'muy',
#   'bien',
#   ',',
#   'el',
#   'precio',
#   'muy',
#   'correcto',
#   '.'],
#  ['Velada', 'agradable', ',', 'os', 'la', 'recomiendo', '.'],
#  ['Muy', 'recomendable', '.'],
#  ['No',
#   'puedo',
#   'más',
#   'que',
#   'recomendarlo',
#   'ya',
#   'que',
#   ',',
#   'sin',
#   'duda',
#   ',',
#   'es',
#   'uno',
#   'de',
#   'los',
#   'valores',
#   'más',
#   'seguros',
#   'de',
#   'la',
#   'Ciudad',
#   'Condal',
#   '.'],
#  ['Mejor',
#   'pasar',
#   'de',
#   'largo.Es',
#   'una',
#   'zona',
#   'en',
#   'la',
#   'que',
#   'no',
#   'falta',
#   'oferta',
#   'hostelera',
#   'con',
#   'mejor',
#   'calidad',
#   '.'],
#  ['Yo',
#   'ya',
#   'e',
#   'celebrado',
#   'muchos',
#   'Cumpleaños',
#   'en',
#   'Restaurantes',
#   ',',
#   'pero',
#   'jamas',
#   'me',
#   'han',
#   'tratado',
#   'tan',
#   'bien',
#   'y',
#   'me',
#   'han',
#   'hecho',
#   'tantos',
#   'Detalles',
#   'k',
#   'me',
#   'gusto',
#   'y',
#   'emociono',
#   'un',
#   'monton',
#   '.'],
#  ['Hola',
#   'JoséEn',
#   'Colette',
#   'no',
#   'tienen',
#   'zona',
#   'de',
#   'no',
#   'fumadores',
#   '.'],
#  ['Bueno', 'lo', 'dicho', 'gracias', '.'],
#  ['Poco',
#   'serio',
#   'que',
#   'confirmen',
#   'disponibilidad',
#   'para',
#   'luego',
#   'cancelarla',
#   'y',
#   'derivarte',
#   'a',
#   'otro',
#   'del',
#   'Grupo',
#   '.'],
#  ['Plato',
#   'degustación',
#   ':',
#   'un',
#   'poco',
#   'abundante',
#   'de',
#   'más',
#   ',',
#   'pero',
#   'bien',
#   'cocinado',
#   '.'],
#  ['Cuando',
#   'está',
#   'lleno',
#   ',',
#   'la',
#   'configuración',
#   'del',
#   'local',
#   'amplifica',
#   'el',
#   'ruido',
#   '.'],
#  ['Despues',
#   'nos',
#   'pusieron',
#   '3',
#   'albondigas',
#   'de',
#   'pollo',
#   'de',
#   'corral',
#   'que',
#   'fue',
#   'sin',
#   'duda',
#   'el',
#   'peor',
#   'plato',
#   '.'],
#  ['Tres', 'tenedores', '?'],
#  ['<->',
#   'El',
#   'servicio',
#   'bastante',
#   'lento',
#   ',',
#   'sobre',
#   'todo',
#   'para',
#   'grupos',
#   'que',
#   'funcionan',
#   'con',
#   'un',
#   'horario',
#   'bastante',
#   'extricto',
#   '.'],
#  ['Un', 'acierto'],
#  ['Nos',
#   'atendieron',
#   'rápidamente',
#   ',',
#   'nuestra',
#   'reserva',
#   'por',
#   'internet',
#   'a',
#   'traves',
#   'de',
#   'bcn',
#   'restaurantes',
#   ',',
#   'perfecto',
#   '.'],
#  ['También', 'la', 'rapidez', 'en', 'el', 'servicio', '.'],
#  ['Hola',
#   'JOse',
#   'nosotros',
#   'hemos',
#   'estado',
#   'varías',
#   'veces',
#   'en',
#   'Pelentos',
#   'de',
#   'Sandiniés',
#   ',',
#   'y',
#   'opino',
#   'como',
#   'tú',
#   ',',
#   'que',
#   'es',
#   'un',
#   'comedor',
#   'muy',
#   'recomendable',
#   '.'],
#  ['Con',
#   'cafés',
#   ',',
#   'vino',
#   'extra',
#   'y',
#   'copas',
#   'al',
#   'final',
#   'salió',
#   'por',
#   '30',
#   '€',
#   '.'],
#  ['y',
#   'para',
#   'colmo',
#   'nos',
#   'querian',
#   'estafar',
#   'cobrando',
#   'de',
#   'mas',
#   '!',
#   '!'],
#  ['La',
#   'próxima',
#   'vez',
#   'pediré',
#   'el',
#   'menú',
#   'degustación',
#   ',',
#   'y',
#   'supongo',
#   'que',
#   'saldrá',
#   'bastante',
#   'más',
#   'económico',
#   ',',
#   'y',
#   'mejorará',
#   'la',
#   'relación',
#   'calidad-precio',
#   '.'],
#  ['El', 'servicio', 'muy', ',', 'muy', 'mal', '.'],
#  ['Este',
#   'es',
#   'mucho',
#   'mas',
#   'elegante',
#   ',',
#   'el',
#   'trato',
#   'muy',
#   'correcto',
#   'y',
#   'la',
#   'ambientacion',
#   'te',
#   'hace',
#   'sentir',
#   'muy',
#   'a',
#   'gusto',
#   '.'],
#  ['me', 'encanta', '.'],
#  ['Tenia',
#   'unas',
#   'expectativas',
#   'muy',
#   'altas',
#   'tras',
#   'haber',
#   'estado',
#   'en',
#   'el',
#   'Barcelonta',
#   'de',
#   'mismo',
#   'grupo',
#   ',',
#   'sinembargo',
#   'me',
#   'decepcionó',
#   'muchísimo',
#   ':',
#   'comida',
#   'recalentada',
#   ',',
#   'mucho',
#   'ruido',
#   ',',
#   'mesas',
#   'muy',
#   'cerca',
#   ',',
#   'trato',
#   'frio',
#   'y',
#   'desagradable',
#   '...'],
#  ['Me',
#   'habian',
#   'recomendado',
#   'este',
#   'restaurante',
#   'y',
#   'la',
#   'verdad',
#   'es',
#   'que',
#   'valia',
#   'la',
#   'pena',
#   'probar',
#   '.'],
#  ['Muy', 'recomendable', '.'],
#  ['Ningún',
#   'problema',
#   'con',
#   'la',
#   'reserva',
#   'hecha',
#   'a',
#   'través',
#   'de',
#   'esta',
#   'WEB',
#   '.'],
#  ['Por',
#   'ponerle',
#   'un',
#   'fallo',
#   'para',
#   'el',
#   'poco',
#   'tiempo',
#   'que',
#   'lleva',
#   'va',
#   'mucha',
#   'gente',
#   'atraída',
#   'por',
#   'el',
#   'diseño',
#   'del',
#   'local',
#   'y',
#   'la',
#   'fama',
#   'que',
#   'va',
#   'cogiendo',
#   'su',
#   'cocina',
#   '.'],
#  ['Volveremos', 'seguro', '!', '!', '!'],
#  ['La', 'reserva', 'estaba', 'hecha', 'para', 'las', '15h30', '.'],
#  ['Parecía',
#   'como',
#   'si',
#   'quiseran',
#   'que',
#   'nos',
#   'fueramos',
#   'enseguida',
#   ',',
#   'para',
#   'así',
#   'llenar',
#   'la',
#   'mesa',
#   'otra',
#   'vez.Para',
#   'postre',
#   ',',
#   'en',
#   'la',
#   'terraza',
#   'de',
#   'arriba',
#   ',',
#   'habia',
#   'un',
#   'evento',
#   'politico',
#   'haciendo',
#   'campaña',
#   '(',
#   'con',
#   'altavoces',
#   ')',
#   ',',
#   'cosa',
#   'que',
#   'a',
#   'mi',
#   ',',
#   'no',
#   'me',
#   'interesaba',
#   'lo',
#   'mas',
#   'minimo',
#   '.'],
#  ['<->', 'ningún', 'plato', 'estuvo', 'acertado', '.'],
#  ['Y',
#   'lo',
#   'mejor',
#   '(',
#   'con',
#   'toda',
#   'la',
#   'ironía',
#   'que',
#   'soy',
#   'capaz',
#   'sin',
#   'faltar',
#   'ni',
#   'insultar',
#   ')',
#   'el',
#   'servicio',
#   '.'],
#  ['Por',
#   'lo',
#   'demás',
#   'el',
#   'lugar',
#   ',',
#   'situación',
#   ',',
#   'elaboración',
#   'y',
#   'la',
#   'relación',
#   'calidad',
#   'precio',
#   'fue',
#   'excelente',
#   'incluso',
#   'ideal',
#   'también',
#   'para',
#   'niños',
#   '.'],
#  ['Muy',
#   'mala',
#   'organización',
#   '.',
#   'Para',
#   'este',
#   'momento',
#   'ya',
#   'estábamos',
#   'logrando',
#   'acomodarnos',
#   'en',
#   'las',
#   'sillas',
#   ',',
#   'muy',
#   'modernas',
#   'pero',
#   'difíciles',
#   '.'],
#  ['Me', 'gusto', 'mucho', 'el', 'menú', '.'],
#  ['Muy', 'buen', 'recuerdo', '.'],
#  ['Estuvimos', 'anoche', ',', '22', 'de', 'febrero', '2015', '.'],
#  ['100', '€', 'garnacha.Edra', 'blanco', 'luz', '.'],
#  ['No',
#   'entiendo',
#   'cómo',
#   'hacen',
#   'con',
#   'las',
#   'parejas',
#   'que',
#   'van',
#   '.'],
#  ['"', 'todo', 'bien', '?'],
#  ['Fuimos',
#   '21',
#   'personas',
#   ',',
#   'trato',
#   'excepcional',
#   ',',
#   'la',
#   'cena',
#   'estuvo',
#   'bien',
#   '.'],
#  ['Poca', 'intimidad', '.'],
#  ['No',
#   'es',
#   'por',
#   'nada',
#   ',',
#   'pero',
#   'mira',
#   'que',
#   'hacéis',
#   'daño',
#   'los',
#   'presuntos',
#   'prescriptores',
#   ',',
#   'con',
#   'vuestra',
#   'presunta',
#   'experiencia',
#   'y',
#   'vuestro',
#   'presunto',
#   'buen',
#   'gusto',
#   '.'],
#  ['Empecé',
#   'a',
#   'comer',
#   ',',
#   'para',
#   'que',
#   'no',
#   'se',
#   'enfriase',
#   'la',
#   'ración',
#   'más',
#   'bien',
#   'escasa',
#   'y',
#   'oh',
#   'sorpresa',
#   'era',
#   'también',
#   'una',
#   'salmuera',
#   'anegada',
#   'en',
#   'tinta',
#   '.'],
#  ['Me', 'lo', 'tendría', 'que', 'pensar', 'mucho', '.'],
#  ['En',
#   'geenral',
#   'está',
#   'bien',
#   ',',
#   'pero',
#   'si',
#   'cuidasen',
#   'esos',
#   'pequeños',
#   'detalles',
#   '(',
#   'sobre',
#   'todo',
#   'la',
#   'distancia',
#   'entre',
#   'mesas',
#   ')',
#   'sería',
#   'superior',
#   '.'],
#  ['Al',
#   'finalizar',
#   'el',
#   'menu',
#   'no',
#   'querian',
#   'hacer',
#   'el',
#   'descuento',
#   'porque',
#   'decían',
#   'que',
#   'el',
#   'descuento',
#   'era',
#   'para',
#   'cenas',
#   'completa',
#   'no',
#   'valia',
#   'para',
#   'platos',
#   'combinados',
#   'sin',
#   'postre',
#   '...'],
#  ['La',
#   'comida',
#   'exquisita',
#   ',',
#   'abundante',
#   ',',
#   'el',
#   'ambiente',
#   'y',
#   'servicio',
#   'muy',
#   'agradables',
#   '.'],
#  ['aceptable', '.'],
#  ['llastima', 'un', 'mica', 'el', 'local', '.'],
#  ['El',
#   'vino',
#   'tiene',
#   'un',
#   'precio',
#   'totalmente',
#   'excesivo',
#   '(',
#   '3',
#   'veces',
#   'el',
#   'precio',
#   'en',
#   'la',
#   'tienda',
#   '.',
#   ')'],
#  ['Excelente',
#   'materia',
#   'prima',
#   'y',
#   'fantástico',
#   'marco',
#   'en',
#   'la',
#   'terraza',
#   'con',
#   'vistas',
#   'al',
#   'Muelle',
#   'de',
#   'España',
#   '.'],
#  ['Sencillamente', ',', 'me', 'ha', 'encantado', '!'],
#  ['Más', 'que', 'recomendable', '.'],
#  ['Nosotros',
#   'estuvimos',
#   'de',
#   'cena',
#   'y',
#   'lo',
#   'pasamos',
#   'francamente',
#   'bien',
#   '.'],
#  ['Cocina',
#   'excelente',
#   ',',
#   'todos',
#   'los',
#   'platos',
#   'que',
#   'pedimos',
#   'estan',
#   'exquisutos'],
#  ['de',
#   'cuidar',
#   'un',
#   'poco',
#   'más',
#   'la',
#   'ortografía',
#   ',',
#   'de',
#   'vez',
#   'en',
#   'cuando',
#   'le',
#   'da',
#   'algunas',
#   'patadas',
#   'a',
#   'la',
#   'misma',
#   ',',
#   'espero',
#   'que',
#   'por',
#   'error',
#   '“',
#   'material',
#   '”',
#   'al',
#   'escribir',
#   'y',
#   'no',
#   'por',
#   'desconocimiento',
#   'del',
#   'lenguaje',
#   '.'],
#  ['Todo',
#   'fue',
#   'tal',
#   'y',
#   'como',
#   'esperabamos',
#   'y',
#   'nos',
#   'habian',
#   'comentado',
#   ',',
#   'buen',
#   'servicio',
#   ',',
#   'buen',
#   'ambiente',
#   'y',
#   'muy',
#   'buena',
#   'comida',
#   ',',
#   'en',
#   'un',
#   'ambiente',
#   'agradable',
#   ',',
#   'sin',
#   'duda',
#   'alguna',
#   'un',
#   'restaurant',
#   'donde',
#   'ir',
#   'cuando',
#   'se',
#   'desea',
#   'que',
#   'todos',
#   'queden',
#   'contentos',
#   '.'],
#  ['Nos',
#   'gusto',
#   'tanto',
#   'que',
#   'al',
#   'día',
#   'siguiente',
#   'fuimos',
#   'a',
#   'cenar',
#   '.'],
#  ['En', 'fin', ',', 'a', 'mi', 'me', 'han', 'cobrado', 'igual', '.'],
#  ['Lo',
#   'único',
#   'que',
#   'en',
#   'la',
#   'pagina',
#   'ponen',
#   'que',
#   'tienen',
#   'platos',
#   'sin',
#   'gluten',
#   'y',
#   'no',
#   'tienen',
#   'información',
#   'ni',
#   'en',
#   'la',
#   'carta',
#   'ni',
#   'el',
#   'mismo',
#   'camarero',
#   '...',
#   'dudaban',
#   'de',
#   'todo',
#   '.'],
#  ['recomendado', '100', '%', 'nosotros', 'volveremos', 'a', 'ir', '.'],
#  ['Mentira',
#   'todo',
#   ',',
#   'deberian',
#   'tener',
#   'ganas',
#   'de',
#   'cerrar',
#   'y',
#   'no',
#   'se',
#   'quisieron',
#   'quedar',
#   'por',
#   'una',
#   'mesa',
#   'de',
#   'dos',
#   'que',
#   'encima',
#   'venian',
#   'con',
#   'un',
#   'dto',
#   'del',
#   '30',
#   '%',
#   'y',
#   'nos',
#   'mintieron',
#   'descaradisimamente',
#   '.'],
#  ['Me',
#   'han',
#   'traído',
#   'otro',
#   'y',
#   'según',
#   'la',
#   'camarera',
#   'le',
#   'han',
#   'cambiado',
#   'un',
#   'ingrediente',
#   '.'],
#  ['Servicio', 'excelente', '.'],
#  ['El', 'corte', 'del', 'jamon', 'en', 'lonchas', 'mas', 'finas', '!'],
#  ['Un',
#   'saludo',
#   'y',
#   'enhorabuena',
#   'por',
#   'esta',
#   'magnifica',
#   'página',
#   ',',
#   'amigo',
#   '.'],
#  ['Contenta',
#   'por',
#   'el',
#   'servicio',
#   'prestado',
#   'que',
#   'fue',
#   'ágil',
#   'y',
#   'gentil',
#   '.'],
#  ['Es',
#   'una',
#   'pena',
#   'que',
#   'inviertiendo',
#   'exitosamente',
#   'en',
#   'lo',
#   'complicado',
#   '(',
#   'local',
#   ',',
#   'materia',
#   'prima',
#   ',',
#   'imagen',
#   ',',
#   'sitio',
#   'web',
#   ')',
#   'se',
#   'pase',
#   'por',
#   'alto',
#   'lo',
#   'básico',
#   ':',
#   'un',
#   'par',
#   'de',
#   'camareros',
#   'díscolos',
#   'que',
#   'hagan',
#   'rebajar',
#   'la',
#   'nota',
#   'de',
#   'un',
#   'cliente',
#   'de',
#   'un',
#   'excelente',
#   'a',
#   'un',
#   'notable',
#   'alto',
#   '.'],
#  ['El',
#   'precio',
#   ',',
#   'por',
#   'lo',
#   'que',
#   'es',
#   'la',
#   'comida',
#   ',',
#   'para',
#   'mi',
#   'gusto',
#   'es',
#   'elevado',
#   '.'],
#  ['<->', 'No', 'pudimos', 'comer', 'ni', 'la', 'mitad', 'de', 'la', 'paella'],
#  ['Solo',
#   'con',
#   'el',
#   'primer',
#   'plato',
#   ',',
#   'tardaron',
#   'media',
#   'hora',
#   'en',
#   'servirlo',
#   'y',
#   'otra',
#   'media',
#   'hora',
#   'en',
#   'servir',
#   'los',
#   'segundos',
#   '...'],
#  ['<->',
#   'no',
#   'es',
#   'un',
#   'restaurante',
#   'ni',
#   'un',
#   'cafe',
#   'de',
#   'cocina',
#   'mediterranea',
#   ',',
#   'es',
#   'un',
#   '"',
#   'lugar',
#   '"',
#   'donde',
#   'tienen',
#   'una',
#   'mini',
#   'carta',
#   'de',
#   'tapas',
#   ',',
#   'servidas',
#   'en',
#   'unas',
#   'bandejas',
#   'en',
#   'las',
#   'que',
#   'dificilmente',
#   'puedes',
#   'usar',
#   'como',
#   'plato',
#   ',',
#   'con',
#   'una',
#   'calidad',
#   'media',
#   'de',
#   'las',
#   'mismas',
#   ',',
#   'y',
#   'que',
#   'para',
#   'subsistir',
#   'ofrecen',
#   'un',
#   'menu',
#   'de',
#   'nueve',
#   'euros',
#   ',',
#   'A',
#   'BUEN',
#   'ENTENDEDOR',
#   'POCAS',
#   'PALABRAS',
#   'BASTAN',
#   '.'],
#  ['gracias'],
#  ['Bien', '.'],
#  ['Correcto', '.'],
#  ['-',
#   'Arroz',
#   'de',
#   'Señorito',
#   ',',
#   'un',
#   'verdadero',
#   'desastre',
#   ',',
#   'pasado',
#   'aplemazado',
#   'y',
#   'al',
#   'cocinero',
#   'se',
#   'le',
#   'cayó',
#   'el',
#   'bote',
#   'de',
#   'pimentón',
#   'de',
#   'la',
#   'vera',
#   'ahumado',
#   ',',
#   'IMPOSIBLE',
#   'COMERLO',
#   '.'],
#  ['Visité', 'Scala', 'hace', 'un', 'año', 'aproximadamente', '.'],
#  ['Insisto',
#   'en',
#   'que',
#   'en',
#   'realidad',
#   'la',
#   'cena',
#   'fué',
#   'para',
#   'un',
#   'persona',
#   ',',
#   'con',
#   'una',
#   'copa',
#   'de',
#   'vino',
#   '.'],
#  ['Es',
#   'de',
#   'los',
#   'pocos',
#   'sitios',
#   'que',
#   'aun',
#   'quedan',
#   'donde',
#   'se',
#   'paga',
#   'en',
#   'función',
#   'de',
#   'como',
#   'se',
#   'come',
#   '.'],
#  ['no', 'volvere', '.'],
#  ['De',
#   'los',
#   '8',
#   'menus',
#   'de',
#   'Navidad',
#   ',',
#   'disponible',
#   'solo',
#   '1',
#   '...',
#   'es',
#   'verdad',
#   'que',
#   'comimos',
#   'bien',
#   ',',
#   'pero',
#   'con',
#   'mucho',
#   'sentido',
#   'del',
#   'humor',
#   '..'],
#  ['IMPORTANTE',
#   ':',
#   'El',
#   'Sr',
#   '.',
#   'Luis',
#   'Argente',
#   'Alejandre',
#   'se',
#   'ha',
#   'puesto',
#   'en',
#   'contacto',
#   'con',
#   'esta',
#   'web',
#   'para',
#   'informar',
#   'que',
#   'ha',
#   'habido',
#   'una',
#   'persona',
#   'que',
#   'ha',
#   'estado',
#   'escribiendo',
#   'comentarios',
#   'en',
#   'su',
#   'nombre',
#   'sobre',
#   'este',
#   'restaurante',
#   '.'],
#  ['Solo',
#   'puedo',
#   'decir',
#   'que',
#   'hay',
#   'calidad',
#   ',',
#   'el',
#   'trato',
#   'y',
#   'la',
#   'atención',
#   'de',
#   'los',
#   'responsables',
#   'del',
#   'restauante',
#   'inmejorable',
#   '.'],
#  ['No',
#   'puedo',
#   'aportar',
#   'nada',
#   'más',
#   'de',
#   'lo',
#   'que',
#   'ya',
#   'he',
#   'podido',
#   'leer',
#   'por',
#   'aquí',
#   '.'],
#  ['Volveremos', '.'],
#  ['La',
#   'fórmula',
#   'sin',
#   'citar',
#   'los',
#   'coeficientes',
#   'ni',
#   'criterios',
#   'a',
#   'valorar',
#   'me',
#   'sirve',
#   'mas',
#   'bien',
#   'de',
#   'poco',
#   ',',
#   'que',
#   'por',
#   'cierto',
#   ',',
#   'espero',
#   ',',
#   'que',
#   'hayas',
#   'teneido',
#   'la',
#   'decencia',
#   'de',
#   'aplicarle',
#   'al',
#   'resultado',
#   'gastronómico',
#   'de',
#   'los',
#   'platos',
#   'un',
#   'coeficiente',
#   'de',
#   'peso',
#   '.'],
#  ['Me',
#   'habían',
#   'comentado',
#   'maravillas',
#   'y',
#   'está',
#   'bien',
#   ',',
#   'pero',
#   'nada',
#   'más',
#   '.'],
#  ['la',
#   'verdad',
#   'es',
#   'que',
#   'ha',
#   'estado',
#   'genial.El',
#   'lugar',
#   'muy',
#   'acogedor',
#   'de',
#   'un',
#   'gusto',
#   'impecable',
#   '.'],
#  ['Una', 'comida', 'deliciosa', '.'],
#  ['De', 'lo', 'mejor', 'de', 'Barcelona', '.'],
#  ['Y',
#   'de',
#   'segundo',
#   'merluza',
#   'con',
#   'almejas',
#   'en',
#   'salsa',
#   'verde',
#   ',',
#   'que',
#   'eran',
#   'pocos',
#   'trozos',
#   ',',
#   'pero',
#   'de',
#   'primera',
#   'calidad',
#   'y',
#   'muy',
#   'bueno',
#   '.'],
#  ['Lo',
#   'he',
#   'visitado',
#   'en',
#   'varias',
#   'ocasiones',
#   'y',
#   'he',
#   'de',
#   'destacar',
#   'la',
#   'excelente',
#   'calidad',
#   'de',
#   'la',
#   'materia',
#   'prima',
#   'y',
#   'el',
#   'saber',
#   'hacer',
#   'en',
#   'la',
#   'cocina',
#   '.'],
#  ['Definitivamente',
#   'no',
#   'volveré',
#   ',',
#   'al',
#   'menos',
#   'pagando',
#   'yo',
#   '.'],
#  ['Pedimos',
#   'al',
#   'a',
#   'carta',
#   'y',
#   'de',
#   'aperitivo',
#   'nos',
#   'sacaron',
#   'una',
#   'cucharita',
#   'de',
#   'brandada',
#   'de',
#   'bacalao',
#   'con',
#   'un',
#   'chupito',
#   'de',
#   'caldo',
#   'de',
#   'ardo',
#   'y',
#   'espuma',
#   'de',
#   'almendras',
#   ',',
#   'la',
#   'verdad',
#   'estaba',
#   'muy',
#   'delicado',
#   '.'],
#  ['Destaca',
#   'en',
#   'todo',
#   'lo',
#   'que',
#   'ofrece',
#   'y',
#   'lo',
#   'hace',
#   'de',
#   'manera',
#   'sobresaliente',
#   'con',
#   'la',
#   'carne',
#   'y',
#   'los',
#   'pescados',
#   '.'],
#  ['Éramos',
#   'un',
#   'grupo',
#   'de',
#   '11',
#   'y',
#   'nos',
#   'prepararon',
#   'una',
#   'mesa',
#   'un',
#   'poco',
#   'apartadita',
#   'y',
#   'el',
#   'tarto',
#   'fue',
#   'muy',
#   'bueno',
#   ',',
#   'lo',
#   'recomiendo',
#   '.'],
#  ['De',
#   'platos',
#   'principales',
#   'unos',
#   '"',
#   'fideus',
#   'rossejats',
#   '"',
#   'y',
#   'un',
#   'tronco',
#   'de',
#   'merluza',
#   'a',
#   'la',
#   'donostiarra',
#   ';',
#   'de',
#   'postre',
#   'el',
#   'famoso',
#   '"',
#   'tiramisú',
#   '"',
#   'de',
#   'la',
#   'casa',
#   'y',
#   'una',
#   'tarta',
#   'de',
#   'manzana',
#   'caramelizada',
#   'con',
#   'helado',
#   'de',
#   'vainilla',
#   '.'],
#  ['Cocina', 'inmejorable', '.'],
#  ['Anselmo',
#   ',',
#   'perdón',
#   'por',
#   'los',
#   'errores',
#   'ortográficos',
#   ',',
#   'son',
#   'fruto',
#   'de',
#   'las',
#   'prisas',
#   ',',
#   'no',
#   'dispongo',
#   'de',
#   'todo',
#   'el',
#   'tiempo',
#   'que',
#   'me',
#   'gustaría',
#   ',',
#   'le',
#   'agradecería',
#   'me',
#   'reportará',
#   'cualquier',
#   'error',
#   'que',
#   'encontrara',
#   ',',
#   'gracias',
#   '.'],
#  ['Fueron', 'un', 'poco', 'lentos', 'en', 'el', 'servicio', '.'],
#  ['El',
#   'trato',
#   'fues',
#   'cordial',
#   'y',
#   'la',
#   'comida',
#   'esplendida',
#   ',',
#   'tuvieron',
#   'un',
#   'par',
#   'de',
#   'detalles',
#   'buenos',
#   'que',
#   'eso',
#   'gusta',
#   'porqeu',
#   'no',
#   'en',
#   'todos',
#   'los',
#   'itios',
#   'lo',
#   'hacen',
#   '.'],
#  ['Muy', 'caro', ',', 'carísimo', 'para', 'la', 'calidad', '.'],
#  ['(',
#   'casi',
#   'lo',
#   'peor',
#   'que',
#   'te',
#   'puede',
#   'pasar',
#   'en',
#   'un',
#   'restaurante',
#   ')',
#   'Me',
#   'gusta',
#   'opinar',
#   'pasado',
#   'un',
#   'tiempo',
#   ',',
#   'cuando',
#   'ya',
#   'has',
#   'asimilado',
#   'la',
#   'experiencia',
#   '.'],
#  ['Buenas',
#   ',',
#   'estuviemos',
#   'anoche',
#   '1/08',
#   '/',
#   '09',
#   'cenando',
#   ',',
#   'reservamos',
#   'para',
#   '4',
#   'dos',
#   'parejas',
#   ',',
#   'ibamos',
#   'a',
#   'pedir',
#   'unas',
#   'raciones',
#   'y',
#   'un',
#   'pescado',
#   'de',
#   'segundo',
#   ',',
#   'pero',
#   'al',
#   'final',
#   'nos',
#   'decidimos',
#   'a',
#   'compartir',
#   'raciones',
#   ',',
#   'el',
#   'tomate',
#   'a',
#   'la',
#   'andaluza',
#   'nos',
#   'lo',
#   'sacaron',
#   'de',
#   'aperitivo',
#   'mientras',
#   'esperabamos',
#   '(',
#   'un',
#   'detalle',
#   ')',
#   'la',
#   'verdad',
#   'que',
#   'pedimos',
#   'casi',
#   'de',
#   'todo',
#   'y',
#   'todo',
#   'era',
#   'de',
#   'buena',
#   'calidad',
#   ',',
#   'acompañado',
#   'de',
#   'un',
#   'Blanc',
#   'Pescador',
#   ',',
#   'la',
#   'verdad',
#   'que',
#   'nos',
#   'quedamos',
#   'muy',
#   'bien',
#   ',',
#   'el',
#   'servicio',
#   'bien',
#   'y',
#   'el',
#   'precio',
#   'pensamos',
#   'que',
#   'nos',
#   'iba',
#   'a',
#   'salir',
#   'mas',
#   'caro',
#   'por',
#   'comer',
#   'asi',
#   'de',
#   'raciones',
#   ',',
#   'pero',
#   'fue',
#   'bastantes',
#   'ajustado',
#   ',',
#   'asi',
#   'que',
#   'lo',
#   'recomiendo',
#   ',',
#   'las',
#   'ortiguillas',
#   'de',
#   'mar',
#   'que',
#   'no',
#   'lo',
#   'habia',
#   'probado',
#   'nunca',
#   'me',
#   'gustaron',
#   'mucho',
#   '.'],
#  ['Volveré', 'seguro', '.'],
#  ['En',
#   'cuanto',
#   'a',
#   'la',
#   'comida',
#   'y',
#   'servicio',
#   'de',
#   'personal',
#   'se',
#   'puede',
#   'afirmar',
#   'que',
#   'estava',
#   'muy',
#   'correcta',
#   '.'],
#  ['<+>',
#   'He',
#   'estado',
#   'muchas',
#   'veces',
#   ',',
#   'lo',
#   'he',
#   'recomendado',
#   'a',
#   'familiares',
#   ',',
#   'amigos',
#   'y',
#   'allegados',
#   'y',
#   'nunca',
#   'ha',
#   'defraudado',
#   'a',
#   'nadie',
#   '.'],
#  ['El', 'precio', 'correcto', 'y', 'adecuado', 'a', 'la', 'comida', '.'],
#  ['Tres',
#   'o',
#   'cuatro',
#   'langostinos',
#   'fritos',
#   'encima',
#   'de',
#   'rúcula',
#   '.'],
#  ['Tipico',
#   'para',
#   'turistas',
#   ',',
#   'griterio',
#   'ensordecedor',
#   'y',
#   'poco',
#   'profesionales',
#   '.'],
#  ['Ha',
#   'sido',
#   'todo',
#   'excelente',
#   ',',
#   'la',
#   'calidad',
#   ',',
#   'los',
#   'tiempos',
#   ',',
#   'el',
#   'ambiente',
#   '(',
#   'quizas',
#   'demasiado',
#   'iluminado',
#   ')',
#   'y',
#   'el',
#   'servicio',
#   '.'],
#  ['Eso',
#   'me',
#   'indica',
#   'que',
#   'voy',
#   'en',
#   'la',
#   'buena',
#   'línea',
#   ',',
#   'en',
#   'la',
#   'de',
#   'no',
#   'venderme',
#   'al',
#   'fácil',
#   'populismo',
#   'de',
#   'alabar',
#   'los',
#   'restaurantes',
#   'modelo',
#   '.'],
#  ['Hay',
#   'vinos',
#   'jóvenes',
#   'muy',
#   'buenos',
#   'de',
#   'Cariñena',
#   'por',
#   'menos',
#   'de',
#   '2',
#   '€',
#   'la',
#   'botella',
#   '.'],
#  ['No',
#   'es',
#   'un',
#   'comentario',
#   'al',
#   'restaurante',
#   'lo',
#   'que',
#   'quiero',
#   'hacer',
#   ',',
#   'sino',
#   'una',
#   'apreciación',
#   'a',
#   'tu',
#   'comentario',
#   '.'],
#  ['El', 'lavabo', 'un', 'poco', 'desastre', '...'],
#  ['Hemos',
#   'comido',
#   'el',
#   'menú',
#   'a',
#   'la',
#   'brasa',
#   'precio',
#   'calidad',
#   'bien',
#   ',',
#   'los',
#   'cayos',
#   'que',
#   'hemos',
#   'probado',
#   'de',
#   '10',
#   '.'],
#  ['pueden', 'mejorar', 'la', 'limpieza', '.'],
#  ['Lo', 'recomiendo', '.'],
#  ['Ya', 'hemos', 'repetido', 'y', 'volveremos', 'a', 'hacerlo', '.'],
#  ['Por',
#   'temas',
#   'logísticos',
#   ',',
#   'busque',
#   'un',
#   'lugar',
#   'dentro',
#   'de',
#   'bcn',
#   ',',
#   'cerca',
#   'del',
#   'hotel',
#   ',',
#   'aunque',
#   'yo',
#   'pensaba',
#   'en',
#   'que',
#   'se',
#   'comería',
#   'mejor',
#   'en',
#   'alguna',
#   'masia',
#   '.'],
#  ['Un', 'acierto', '.'],
#  ['Se',
#   'lo',
#   'recomiendo',
#   'a',
#   'todos',
#   'los',
#   'que',
#   'esten',
#   'buscando',
#   'un',
#   'lugar',
#   'donde',
#   'celebrar',
#   'una',
#   'comida',
#   'entre',
#   'amigos',
#   'o',
#   'de',
#   'trabajo',
#   'y',
#   'tambien',
#   'a',
#   'parejas',
#   'ya',
#   'que',
#   'se',
#   'trata',
#   'de',
#   'un',
#   'lugar',
#   'tranquilo',
#   'y',
#   'agradable',
#   'con',
#   'unos',
#   'platos',
#   'sencillos',
#   'y',
#   'con',
#   'mucha',
#   'calidad',
#   '.'],
#  ['Nos',
#   'dieron',
#   'la',
#   'opción',
#   'de',
#   'repetir',
#   'calsots',
#   ',',
#   'siempre',
#   'es',
#   'un',
#   'detalle',
#   'que',
#   'se',
#   'agradece',
#   'pero',
#   'no',
#   'suficiente',
#   'para',
#   'aprobar',
#   'el',
#   'servicio',
#   '.',
#   ')'],
#  ['Lo', 'recomiendo', ',', 'volveremos', '.'],
#  ['El', 'menú', 'calçotada', 'magnífico'],
#  ['En',
#   'los',
#   'postres',
#   'la',
#   'ausencia',
#   'del',
#   'chocolate',
#   'me',
#   'parece',
#   'personalmente',
#   'imperdonable',
#   ',',
#   'pero',
#   'eso',
#   'ya',
#   'es',
#   'una',
#   'cuestión',
#   'personal',
#   '.'],
#  ['Además', 'te', 'leen', 'aún', 'más', 'sugerencias', '.'],
#  ['El', 'restaurante', 'es', 'precioso', ',', 'moderno', 'y', 'acogedor', '.'],
#  ['Estuve',
#   'hace',
#   'dos',
#   'semanas',
#   ',',
#   'volvia',
#   'despues',
#   'de',
#   '2',
#   'años',
#   '(',
#   'entonces',
#   'me',
#   'maravilló',
#   ')',
#   'pero',
#   'ahora',
#   'en',
#   '2010',
#   'lo',
#   'vi',
#   'un',
#   'poco',
#   'dejado',
#   ',',
#   'no',
#   'me',
#   'sorprendio',
#   'nada',
#   'y',
#   'la',
#   'impresión',
#   'que',
#   'me',
#   'dió',
#   'es',
#   'que',
#   'tenían',
#   'poca',
#   'variedad',
#   'para',
#   'elegir',
#   '.'],
#  ['La', 'comida', 'divina', '.'],
#  ['<+>', 'personal', 'amable', '.'],
#  ['Buenisima', 'la', 'langosta', 'a', 'la', 'plancha'],
#  ['No',
#   'es',
#   'nada',
#   'barato',
#   'pero',
#   'ofrece',
#   'calidad',
#   'y',
#   'los',
#   'platos',
#   'están',
#   'bien',
#   'cocinados',
#   'y',
#   'con',
#   'elementos',
#   'frescos',
#   '.'],
#  ['Si',
#   'siguen',
#   'así',
#   'pienso',
#   'que',
#   'pueden',
#   'tener',
#   'un',
#   'buen',
#   'futuro',
#   '.'],
#  ['Yo',
#   'no',
#   'iré',
#   'a',
#   'este',
#   'restaurante',
#   ',',
#   'íré',
#   'a',
#   'lo',
#   'seguro',
#   'y',
#   'me',
#   'quedaré',
#   'por',
#   'La',
#   'Matilde',
#   '…'],
#  ['Hemos',
#   'vuelto',
#   ',',
#   'hoy',
#   'martes',
#   '18',
#   'de',
#   'junio',
#   'de',
#   '2013',
#   ',',
#   'despues',
#   'de',
#   'un',
#   'año',
#   'aproximadamente',
#   ',',
#   'para',
#   'una',
#   'celebración',
#   ',',
#   'y',
# ...
#   'conservadoras',
#   'en',
#   'lo',
#   'que',
#   'a',
#   'sabores',
#   'respecta',
#   '-',
#   'salvo',
#   'en',
#   'el',
#   'trato',
#   'a',
#   'las',
#   'verduras',
#   '.'],
#  ['El',
#   'servicio',
#   'muy',
#   'correcto',
#   'tanto',
#   'en',
#   'atención',
#   'como',
#   'en',
#   'educación',
#   '.'],
#  ['Siempre',
#   'bebemos',
#   'cava',
#   'y',
#   'nos',
#   'lo',
#   'sacan',
#   'muy',
#   'frio',
#   ',',
#   'como',
#   'debe',
#   'ser',
#   'y',
#   'en',
#   'pocos',
#   'sitios',
#   'te',
#   'lo',
#   'sacan',
#   'correctamente',
#   '.'],
#  ['solo',
#   'dijo',
#   'que',
#   'es',
#   'un',
#   'sitio',
#   'alucinate',
#   ',',
#   'comida',
#   'sevicio',
#   'y',
#   'decoracion',
#   ',',
#   'lo',
#   'que',
#   'mas',
#   'me',
#   'gusto',
#   'fue',
#   'la',
#   'comida',
#   'ya',
#   'que',
#   'es',
#   'de',
#   'muy',
#   'buena',
#   'calidad',
#   ',',
#   'espero',
#   'que',
#   'en',
#   'un',
#   'futuro',
#   'se',
#   'igual',
#   'y',
#   'que',
#   'no',
#   'cambie',
#   '.'],
#  ['Un', 'precio', 'razonable', ',', 'en', 'mi', 'opinión', '.'],
#  ['Un', '"', 'Blue', 'chip', '"', 'de', 'la', 'restauración', '.'],
#  ['El',
#   'servicio',
#   'es',
#   'muy',
#   'bueno',
#   'y',
#   'la',
#   'calidad',
#   'de',
#   'la',
#   'comida',
#   'al',
#   'mismo',
#   'nivel',
#   '.'],
#  ['Comida', 'y', 'vistas', 'excepcionale', '.'],
#  ['Muy', 'bien', 'adaptados', 'los', 'menús', 'para', 'parejas', '.'],
#  ['De',
#   'segundo',
#   ',',
#   'los',
#   'dos',
#   'pedimos',
#   'lubina',
#   'a',
#   'la',
#   'sal',
#   '.'],
#  ['El',
#   'ambiente',
#   'es',
#   'unico',
#   ',',
#   'el',
#   'servicio',
#   'muy',
#   'atento',
#   'y',
#   'la',
#   'comida',
#   'un',
#   '10',
#   '.'],
#  ['Mi', 'experiencia', 'es', 'negativa', 'y', 'no', 'volvere', 'mas', '.'],
#  ['Trato',
#   'agradable',
#   ',',
#   'buen',
#   'servicio',
#   ',',
#   'la',
#   'comida',
#   'llegaba',
#   'en',
#   'su',
#   'punto',
#   '…',
#   '.'],
#  ['Les', 'joderas', 'seguro', '.'],
#  ['Es',
#   'lo',
#   'único',
#   'reseñable',
#   ',',
#   'debería',
#   'ser',
#   'de',
#   '750cc',
#   ',',
#   'Bien',
#   'calidad-precioLo',
#   'recomiendo'],
#  ['El',
#   'restaurants',
#   'comimos',
#   'muy',
#   'bien',
#   'y',
#   'ademas',
#   'un',
#   'servicio',
#   'encantador',
#   'y',
#   'eficiente',
#   '.'],
#  ['Sí',
#   'Manolo',
#   ',',
#   'tienes',
#   'razón',
#   ',',
#   'no',
#   'me',
#   'he',
#   'explicado',
#   'bien',
#   ',',
#   'quería',
#   'decir',
#   'que',
#   'no',
#   'es',
#   'un',
#   'precio',
#   'bajo',
#   'como',
#   'para',
#   'poder',
#   'dar',
#   'todo',
#   'por',
#   '“',
#   'bueno',
#   '”',
#   ',',
#   'que',
#   'hay',
#   'que',
#   'exigir',
#   'un',
#   'poco',
#   'más',
#   '.'],
#  ['Muy',
#   'buena',
#   'calidad',
#   'de',
#   'alimentos',
#   'y',
#   'muy',
#   'bien',
#   'cocinados',
#   '.'],
#  ['El',
#   'único',
#   '“',
#   'pero',
#   '”',
#   'es',
#   'el',
#   'tiempo',
#   'de',
#   'espera',
#   'entre',
#   'plato',
#   'y',
#   'plato',
#   ',',
#   'pero',
#   'entiendo',
#   'que',
#   'no',
#   'es',
#   'excesivo',
#   'si',
#   'tenemos',
#   'en',
#   'cuenta',
#   'que',
#   'los',
#   'platos',
#   'son',
#   'muy',
#   'elaborados',
#   'y',
#   'se',
#   'hacen',
#   'en',
#   'el',
#   'momento',
#   '.'],
#  ['Conocimos',
#   'su',
#   'oferta',
#   'veraniega',
#   'y',
#   'dijimos',
#   'que',
#   'volveríamos',
#   '.'],
#  ['Anonadado',
#   'me',
#   'hallo',
#   ',',
#   '¿',
#   'y',
#   'cómo',
#   'has',
#   'llegado',
#   'a',
#   'tales',
#   'conclusiones',
#   '?',
#   ',',
#   'porque',
#   'no',
#   'utilizo',
#   'las',
#   'mayúsculas',
#   'en',
#   'un',
#   'gentilicio',
#   '?',
#   '.'],
#  ['El',
#   'camarero',
#   'nos',
#   'atendió',
#   'genial',
#   ',',
#   'alegre',
#   ',',
#   'amable',
#   ',',
#   'simpático',
#   'y',
#   'atento',
#   '.'],
#  ['-',
#   'EL',
#   'SERVICIO',
#   ':',
#   'dice',
#   'usted',
#   'que',
#   'en',
#   'ningún',
#   'momento',
#   'empatizó',
#   'y',
#   'que',
#   'le',
#   'gusta',
#   'que',
#   'len',
#   'pregunten',
#   '…',
#   '”',
#   'Pues',
#   'fíjese',
#   ',',
#   'a',
#   'mí',
#   'me',
#   'gusta',
#   'que',
#   'no',
#   'me',
#   'molesten',
#   '.'],
#  ['Buena',
#   'calidad',
#   'en',
#   'los',
#   'productos',
#   'y',
#   'un',
#   'muy',
#   'buen',
#   'servicio',
#   'recibido',
#   '.'],
#  ['Debe', 'mejorar', 'muy', 'mucho', 'su', 'carta', 'de', 'vinos', '.'],
#  ['Los', 'arroces', 'y', 'suquets', 'inmejorables', '.'],
#  ['Servicio', 'correcto', ',', 'buena', 'relación', 'calidad-precio'],
#  ['Saludos'],
#  ['(', 'le', 'han', 'puesto', 'mas', 'sal', ')', '.'],
#  ['Una',
#   'vergüenza',
#   'lo',
#   'que',
#   'nos',
#   'han',
#   'cobrado',
#   ',',
#   'han',
#   'sugerido',
#   'los',
#   'entrantes',
#   'y',
#   'nos',
#   'han',
#   'cobrado',
#   '9',
#   'euros',
#   'por',
#   'cada',
#   'plato',
#   'de',
#   'pan',
#   'con',
#   'tomate',
#   '.',
#   'Hemos',
#   'ido',
#   '12',
#   'y',
#   'hemos',
#   'pagado',
#   'caso',
#   '700',
#   'euros',
#   'y',
#   'hemos',
#   'tenido',
#   'que',
#   'pedir',
#   'que',
#   'nos',
#   'invitaran',
#   'a',
#   'un',
#   'chupito',
#   '.'],
#  ['Volveremos'],
#  ['Extremadamente', 'caro', 'por', 'el', 'tipo', 'de', 'cocina', '.'],
#  ['El',
#   'trato',
#   'muy',
#   'bueno',
#   ',',
#   'muy',
#   'amables',
#   ',',
#   'el',
#   'arroz',
#   'exquisito',
#   'y',
#   'a',
#   'mitad',
#   'de',
#   'precio',
#   ',',
#   'lo',
#   'recomiendo',
#   '.'],
#  ['Hice',
#   'la',
#   'reserva',
#   'a',
#   'través',
#   'de',
#   'esta',
#   'página',
#   'y',
#   'reservé',
#   'el',
#   'Menú',
#   'Diario',
#   '.'],
#  ['no', 'está', 'mal', 'como', 'comienzo', '.'],
#  ['Muy', 'correcto'],
#  ['Eramos',
#   '15',
#   'y',
#   'estuvo',
#   'muy',
#   'bién',
#   'para',
#   'ser',
#   'en',
#   'el',
#   'centro',
#   'de',
#   'Barcelona',
#   '.'],
#  ['Delicioso', '!', '!', '!'],
#  ['Y',
#   'el',
#   'segundo',
#   ',',
#   'paletilla',
#   'de',
#   'ternasco',
#   ',',
#   'de',
#   'tamaño',
#   'un',
#   'pelín',
#   'escaso',
#   '(',
#   'era',
#   'en',
#   'forma',
#   'de',
#   'redondo',
#   ')',
#   'y',
#   'muy',
#   'rico',
#   '.'],
#  ['La',
#   'relación',
#   'calidad',
#   'precio',
#   'está',
#   'muy',
#   'poco',
#   'ajustada',
#   '.'],
#  ['Recomendable', '¡', '¡', '¡'],
#  ['Los',
#   'camareros',
#   'muy',
#   'atentos',
#   ',',
#   'y',
#   'la',
#   'comida',
#   'excelente',
#   ',',
#   'lo',
#   'recomendaré'],
#  ['Sin', 'duda', 'es', 'un', 'sitio', 'que', 'recomiendo', '.'],
#  ['¿', 'Hay', 'separación', 'entre', 'mesas', '?'],
#  ['Tampoco',
#   'he',
#   'probado',
#   'nunca',
#   'unas',
#   'pizzas',
#   'al',
#   'horno',
#   'de',
#   'leña',
#   'tan',
#   'buenas',
#   '.'],
#  ['Un',
#   'placer',
#   'que',
#   'puedas',
#   'comer',
#   'a',
#   'las',
#   '16:00',
#   'tan',
#   'tranquilamente',
#   'y',
#   'tan',
#   'gusto',
#   '.'],
#  ['Recomiendo',
#   'encarecidamente',
#   'optar',
#   'por',
#   'el',
#   'Wok',
#   'de',
#   'Via',
#   'Universitas',
#   'sin',
#   'ninguna',
#   'duda',
#   ',',
#   'esta',
#   'cerca',
#   'de',
#   'ahi',
#   '.'],
#  ['Además',
#   'teniendo',
#   'que',
#   'correr',
#   'para',
#   'salir',
#   'a',
#   'tiempo',
#   ',',
#   'porque',
#   'hacen',
#   'turnos',
#   'para',
#   'cenar',
#   '.'],
#  ['Vino', 'tinto', 'de', 'la', 'D', '.', 'O', '.'],
#  ['Servicio', 'excelente', 'y', 'comida', 'muy', 'bien', '.'],
#  ['Si',
#   'organizáis',
#   'algo',
#   'en',
#   'grupo',
#   'y',
#   'queréis',
#   'quedar',
#   'bien',
#   'con',
#   'los',
#   'comensales',
#   'os',
#   'lo',
#   'recomiendo',
#   'sin',
#   'duda',
#   '.'],
#  ['Un',
#   'restaurante',
#   'exceccional',
#   ',',
#   'con',
#   'una',
#   'calidad',
#   'de',
#   'productos',
#   'impresionantes',
#   ',',
#   'el',
#   'pescado',
#   'recien',
#   'traido',
#   'de',
#   'San',
#   'SEBASTIAN',
#   ',',
#   'y',
#   'la',
#   'carne',
#   ',',
#   'en',
#   'pocos',
#   'restaurantes',
#   'la',
#   'comes',
#   'como',
#   'en',
#   'la',
#   'sidreria.volveria',
#   ',',
#   'siempre',
#   'que',
#   'pudiese'],
#  ['Fue',
#   'genial',
#   ',',
#   'nos',
#   'atendieron',
#   'muy',
#   'bien',
#   'y',
#   'relacion',
#   'calidad',
#   'precio',
#   'buenisima',
#   '.'],
#  ['En',
#   'cuanto',
#   'a',
#   'la',
#   'comida',
#   ',',
#   'bien',
#   'pero',
#   'nada',
#   'exclusivo',
#   'ni',
#   'sorprendente',
#   '.'],
#  ['fuimos',
#   'a',
#   'hacer',
#   'una',
#   'celebracion',
#   'familiar',
#   'a',
#   'HOSTERIA',
#   'BOTIN',
#   'DEL',
#   'CORREGIDOR',
#   'en',
#   'c',
#   '/',
#   'Josefa',
#   'Amar',
#   'y',
#   'Borbom',
#   ',',
#   'era',
#   'la',
#   'confirmacion',
#   'de',
#   'mi',
#   'hija',
#   ',',
#   'eramos',
#   '15',
#   'personas',
#   'y',
#   'realmente',
#   'salimos',
#   'muy',
#   'satisfechos',
#   ',',
#   'la',
#   'relacion',
#   'calidad',
#   'precio',
#   'fue',
#   'muy',
#   'favorable',
#   ',',
#   'el',
#   'trato',
#   'muy',
#   'amable',
#   'y',
#   'cordial',
#   'y',
#   'el',
#   'comedor',
#   'arriba',
#   'muy',
#   'agradable',
#   '.'],
#  ['Es', 'un', 'sitio', 'correcto', ',', 'sin', 'mas', '.'],
#  ['Este',
#   'restaurante',
#   'goza',
#   'de',
#   'una',
#   'homogeneidad',
#   'envidiable',
#   '.'],
#  ['No',
#   'volveremos',
#   ',',
#   'nos',
#   'quedamos',
#   'con',
#   '“',
#   'La',
#   'Casa',
#   'de',
#   'Mar',
#   '”',
#   '.'],
#  ['no',
#   'os',
#   'conocia',
#   'y',
#   'el',
#   'sábado',
#   'dia',
#   '5,09',
#   'estuve',
#   'cenando',
#   'con',
#   'el',
#   'grupo',
#   'de',
#   'Singles',
#   'Bcn',
#   'y',
#   'fue',
#   'un',
#   'verdadero',
#   'desastre',
#   ',',
#   'no',
#   'se',
#   'cumplió',
#   'con',
#   'lo',
#   'expuesto',
#   'en',
#   'el',
#   'menú',
#   'y',
#   'el',
#   'servicio',
#   '"',
#   'horrendo',
#   '"',
#   'yo',
#   'casi',
#   'diria',
#   'rozando',
#   'la',
#   'mala',
#   'educación',
#   ',',
#   'fue',
#   'una',
#   'lástima',
#   ',',
#   'todo',
#   'el',
#   'grupo',
#   'de',
#   'la',
#   'mesa',
#   'quedó',
#   'sin',
#   'ganas',
#   'de',
#   'volver',
#   '.'],
#  ['<+>', 'Nunca', 'falla', '.'],
#  ['Enhorabuena', 'y', 'gracias', 'por', 'vuestro', 'trabajo', '.'],
#  ['Un', 'pelo', 'más', 'caro', 'de', 'lo', 'que', 'esperábamos', '.'],
#  ['Si',
#   'sirven',
#   'tortilla',
#   'de',
#   'patata',
#   'tiene',
#   'que',
#   'ser',
#   'buena',
#   'te',
#   'cobren',
#   '2',
#   'euros',
#   'o',
#   'te',
#   'cobren',
#   '100',
#   ',',
#   'el',
#   'incremento',
#   'del',
#   'precio',
#   'se',
#   'deberá',
#   'a',
#   'otros',
#   'factores',
#   'como',
#   'puede',
#   'ser',
#   'la',
#   'profesionalidad',
#   ',',
#   'números',
#   'de',
#   'mesas',
#   'por',
#   'camarero',
#   ',',
#   'decoración',
#   'del',
#   'local',
#   'y',
#   'otros',
#   'factores',
#   'externos',
#   'a',
#   'la',
#   'comida',
#   'propiamente',
#   '.'],
#  ['<+>', 'La', 'camarera', 'catalana', 'que', 'nos', 'atendio', '.'],
#  ['Enhorabuena', '!', '!', ',', 'ahora', 'sí', 'lo', 'has', 'entendido', '.'],
#  ['Siga',
#   'así',
#   ',',
#   'diga',
#   'lo',
#   'que',
#   'piensa',
#   ',',
#   'no',
#   'se',
#   'venda',
#   'al',
#   '“',
#   'marketing',
#   '”',
#   'ni',
#   'a',
#   'las',
#   'corrientes',
#   'de',
#   'opinión',
#   'en',
#   'boga',
#   ',',
#   'muchos',
#   'se',
#   'lo',
#   'agradeceremos',
#   '.'],
#  ['Nos', 'sentimos', 'muy', 'a', 'gusto', '.'],
#  ['Alguna', 'risa', ',', 'pero', 'muy', 'normalito', '.'],
#  ['El',
#   'postre',
#   '…',
#   '2',
#   'pastelitos',
#   'de',
#   'los',
#   'pequeños',
#   'de',
#   'cualquier',
#   'pastelería',
#   'por',
#   'persona',
#   '.'],
#  ['comimos',
#   'el',
#   'domingo',
#   '20',
#   'de',
#   'octubre',
#   'y',
#   'tenemos',
#   'que',
#   'decir',
#   'que',
#   'estuvo',
#   'genial',
#   ',',
#   'probamos',
#   'una',
#   'ensalada',
#   'con',
#   'bonito',
#   'escabechado',
#   'de',
#   'la',
#   'casa',
#   'muy',
#   'bueno',
#   ',',
#   'las',
#   'carnes',
#   'muy',
#   'bien',
#   'elaboradas',
#   ',',
#   'los',
#   'postres',
#   'casi',
#   'sobraban',
#   ',',
#   'pero',
#   'había',
#   'que',
#   'hacer',
#   'un',
#   'esfuerzo',
#   'que',
#   'mereció',
#   'la',
#   'pena',
#   'y',
#   'bastantes',
#   'vinos',
#   'para',
#   'poder',
#   'elegir',
#   '.'],
#  ['En', 'total', ',', '190', 'euros', 'para', 'seis', 'personas', '.'],
#  ['Buen',
#   'servicio',
#   ',',
#   'buena',
#   'comida',
#   'y',
#   'a',
#   'precio',
#   'medio',
#   '.'],
#  ['¿',
#   'Cómo',
#   'vamos',
#   'a',
#   'pedir',
#   'un',
#   'vino',
#   'si',
#   'no',
#   'somos',
#   'adivinos',
#   'de',
#   'los',
#   'platos',
#   'que',
#   'nos',
#   'van',
#   'a',
#   'sacar',
#   '?',
#   'En',
#   'este',
#   'punto',
#   'fallan',
#   '.'],
#  ['Respecto',
#   'a',
#   'lo',
#   'de',
#   'los',
#   'niños',
#   'y',
#   'las',
#   'escaleras',
#   'creo',
#   'que',
#   'es',
#   'nuestro',
#   'problema',
#   'ya',
#   'nos',
#   'creceran',
#   ',',
#   'a',
#   'mi',
#   'me',
#   'ha',
#   'tocado',
#   'de',
#   'todo',
#   'estar',
#   'bastante',
#   'pretos',
#   'y',
#   'estar',
#   'muy',
#   'comodos',
#   ',',
#   'de',
#   'cualquier',
#   'modo',
#   'vamos',
#   'a',
#   'comer',
#   'y',
#   'eso',
#   'hago',
#   'me',
#   'relajo',
#   ',',
#   'como',
#   'y',
#   'agradezco',
#   'lo',
#   'que',
#   'me',
#   'dan',
#   'sin',
#   'pedirlo',
#   'qu',
#   'es',
#   'educación',
#   ',',
#   'cariño',
#   'y',
#   'una',
#   'sonrisa',
#   '.'],
#  ['El',
#   'local',
#   'impresionante',
#   ',',
#   'con',
#   'una',
#   'terraza',
#   'preciosa',
#   'con',
#   'vistas',
#   'al',
#   'puerto',
#   '.'],
#  ['Algo',
#   'caro',
#   ',',
#   'pero',
#   'la',
#   'carta',
#   'tiene',
#   'bastante',
#   'variedad',
#   'y',
#   'la',
#   'calidad',
#   'es',
#   'buena',
#   '.'],
#  ['Un', 'sito', 'ideal', 'para', 'una', 'comida', 'de', 'negocios', '.'],
#  ['<->', 'No', 'lo', 'se'],
#  ['Todo',
#   'fue',
#   'perfecto',
#   ',',
#   'tanto',
#   'la',
#   'atención',
#   'del',
#   'personal',
#   'como',
#   'sus',
#   'productos',
#   '.'],
#  ['por', 'lo', 'demás', '10', '.'],
#  ['Restaurante',
#   'para',
#   'no',
#   'tirar',
#   'cohetes',
#   'pero',
#   'en',
#   'general',
#   'sales',
#   'satisfecho',
#   '.'],
#  ['Aunque',
#   'fuera',
#   'más',
#   'o',
#   'menos',
#   'normal',
#   'el',
#   'resto',
#   '(',
#   'los',
#   'entremeses',
#   'de',
#   'balneario',
#   'sí',
#   'son',
#   'los',
#   'mismos',
#   'que',
#   'los',
#   'que',
#   'aparecen',
#   'en',
#   'la',
#   'foto',
#   ')',
#   ',',
#   'se',
#   'dejaba',
#   'comer',
#   '.'],
#  ['El',
#   'cazón',
#   '(',
#   'bienmesabe',
#   ')',
#   'ni',
#   'cazón',
#   'ni',
#   'bienmesabe',
#   'era',
#   'TIBURÓN',
#   'MULTIVITAMÍNICO',
#   '(',
#   'eso',
#   'me',
#   'dijeron',
#   ')',
#   '.'],
#  ['Realmente', 'calidad', 'muy', 'buena', 'y', 'buena', 'atención', '.'],
#  ['Comida', 'y', 'vistas', 'excepcionales', '.'],
#  ['Fuimos', 'a', 'probar', 'el', 'menu', 'del', 'cava', '.'],
#  ['Buena', 'relacion', 'calidad', 'precio'],
#  ['El', 'proceso', 'fue', 'correcto', 'en', 'todos', 'los', 'sentidos', '.'],
#  ['han', 'subido', 'bastante', 'los', 'precios', '.'],
#  ['El',
#   'único',
#   'inconveniente',
#   'el',
#   'ruido',
#   '...',
#   'pero',
#   'vaya',
#   '...',
#   'todo',
#   'estupendo',
#   '!',
#   '!'],
#  ['Buena', 'comida', 'y', 'buen', 'servicio', '.'],
#  ['Hoy', 'hemos', 'comido', 'en', 'el', 'Barceloneta', '.'],
#  ['Un', 'sitio', 'precioso', ',', 'con', 'un', 'ambiente', 'exquisito', '.'],
#  ['No', 'perderse', 'el', 'sorbete', 'de', 'mojito', '.'],
#  ['Además',
#   ',',
#   'hacía',
#   'tiempo',
#   'que',
#   'no',
#   'veníamos',
#   'a',
#   'esta',
#   'zona',
#   'de',
#   'Barcelona',
#   'en',
#   'el',
#   'Born',
#   ',',
#   'y',
#   'ha',
#   'quedado',
#   'ahora',
#   'increíble',
#   'de',
#   'bonito',
#   '.'],
#  ['Fuimos',
#   '2',
#   'personas',
#   'a',
#   'tomar',
#   'el',
#   'menú',
#   'de',
#   'calçotada',
#   'y',
#   'la',
#   'verdad',
#   'es',
#   'que',
#   'el',
#   'servicio',
#   'fue',
#   'bueno',
#   'y',
#   'la',
#   'comida',
#   'también',
#   '.'],
#  ['Tanto',
#   'el',
#   'postre',
#   'como',
#   'el',
#   'vino',
#   ',',
#   'fueron',
#   'consejo',
#   'del',
#   'maitre',
#   ',',
#   'y',
#   'la',
#   'verdad',
#   'que',
#   'muy',
#   'acertados',
#   '.'],
#  ['<->', 'Nada'],
#  ['Muy',
#   'buen',
#   'servicio',
#   'y',
#   'hemos',
#   'cenado',
#   'sinceramente',
#   'bien',
#   '.'],
#  ['Comida',
#   ',',
#   'entrantes',
#   'correctos',
#   'salvo',
#   'los',
#   'pinchos',
#   'mal',
#   ',',
#   'el',
#   'arroz',
#   'caldoso',
#   'de',
#   'cigalas',
#   'bien',
#   '.'],
#  ['El',
#   'Pan',
#   'con',
#   'tomate',
#   'te',
#   'lo',
#   'sirven',
#   'ya',
#   'untado',
#   'y',
#   'tampoco',
#   'nos',
#   'convencio',
#   ',',
#   'algunos',
#   'tenían',
#   'demasiado',
#   'tomate',
#   'y',
#   'personalmente',
#   'me',
#   'gusta',
#   'hacermelo',
#   'con',
#   'un',
#   'poco',
#   'de',
#   'ajo',
#   'untado',
#   '.'],
#  ['Tomamos',
#   'el',
#   'menú',
#   'calçotada',
#   'y',
#   'estuvo',
#   'muy',
#   'correcto',
#   'con',
#   'posibilidad',
#   'de',
#   'repetir',
#   'calçots',
#   'y',
#   'la',
#   'bebida',
#   'incluida',
#   'sin',
#   'límite',
#   '.'],
#  ['Que',
#   'si',
#   'me',
#   'molestaba',
#   'me',
#   'cambiaban',
#   'de',
#   'mesa',
#   '!',
#   '!',
#   '!',
#   ',',
#   'despues',
#   'de',
#   'tanto',
#   'tiempo',
#   'de',
#   'aplicacion',
#   'de',
#   'la',
#   'ley',
#   'yo',
#   'me',
#   'tenia',
#   'que',
#   'cambiar',
#   '!',
#   '!',
#   '!'],
#  ['Te',
#   'aseguro',
#   'que',
#   ',',
#   'en',
#   'cuanto',
#   'tenga',
#   'ocasión',
#   ',',
#   'los',
#   'probaré',
#   'y',
#   'aquí',
#   'mismo',
#   'te',
#   'daré',
#   'la',
#   'razón',
#   'en',
#   'caso',
#   'de',
#   'que',
#   'me',
#   'gusten',
#   '.'],
#  ['correcto'],
#  ['La', 'comida', 'buena', ',', 'pero', 'NO', 'SORPRENDENTE', '.'],
#  ['La', 'carne', 'y', 'butifarra', 'también', 'estaba', 'muy', 'bien', '.'],
#  ['La', 'tira', 'de', 'asado', 'normal', ',', 'nada', 'extraordinaria', '.'],
#  ...]

# %%
# word = ['disfrutemos', 'de', 'una', 'buenísima', 'calidad', 'en', 'el', '.']
# word = ES_train_words[0]
# start_viterbi(word, ES_tags_unique, ES_emission_parameters, ES_transition_parameters)
# print(f'viterbi_values: {viterbi_values}')
# ES_generated_tag_list = generate_predictions_viterbi(word, ES_tags_unique, ES_emission_parameters, ES_transition_parameters)
# print(ES_generated_tag_list)


# Run and output Viterbi for ES
ES_predicted_tags_list = []
for word in ES_test_words:
    viterbi_values = {}
    start_viterbi(word, ES_tags_unique, ES_emission_parameters, ES_transition_parameters)
    ES_generated_tag_list = generate_predictions_viterbi(word, ES_tags_unique, ES_emission_parameters, ES_transition_parameters)
    ES_predicted_tags_list.append(ES_generated_tag_list)

write_to_predicted_file_part2(ES_PART3_PREDICTED_DATA_FILE, ES_test_words, ES_predicted_tags_list)


# Run and output Viterbi for RU
RU_predicted_tags_list = []
for word in RU_test_words:
    viterbi_values = {}
    start_viterbi(word, RU_tags_unique, RU_emission_parameters, RU_transition_parameters)
    RU_generated_tag_list = generate_predictions_viterbi(word, RU_tags_unique, RU_emission_parameters, RU_transition_parameters)
    RU_predicted_tags_list.append(RU_generated_tag_list)

write_to_predicted_file_part2(RU_PART3_PREDICTED_DATA_FILE, RU_test_words, RU_predicted_tags_list)

# %%
from EvalScript.evalResult import get_observed, get_predicted,compare_observed_to_predicted

def evaluateScores(actual_file, predicted_file):
    with open(predicted_file, encoding="utf8") as f:
        predicted = f.read().splitlines()

    with open(actual_file, encoding="utf8") as f:
        actual = f.read().splitlines()
   
    compare_observed_to_predicted(get_observed(actual), get_predicted(predicted))

evaluateScores(ES_ACTUAL_DATA_FILE, ES_PART3_PREDICTED_DATA_FILE)
# Out:
# #Entity in gold data: 255
# #Entity in prediction: 292
#
# #Correct Entity : 1
# Entity  precision: 0.0034
# Entity  recall: 0.0039
# Entity  F: 0.0037
#
# #Correct Sentiment : 0
# Sentiment  precision: 0.0000
# Sentiment  recall: 0.0000
# Sentiment  F: 0.0000
